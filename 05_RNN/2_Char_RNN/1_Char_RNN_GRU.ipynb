# %% [markdown]
# # Character Recurrent Neural Network
# - Mimicing Shakespeare's writing style
# - Gated Recurrent Unit(GRU)
#
# ![alt text](./GRU.png)

# %% [markdown]
# ## 1. Settings
# ### 1) Import required libraries

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

# %%
import unidecode
import string
import random
import re
import time, math

# %% [markdown]
# ## 2) Hyperparameter

# %%
num_epochs = 20000
print_every = 100
plot_every = 10
chunk_len = 200
hidden_size = 100
batch_size =1
num_layers = 1
lr = 0.002

# %% [markdown]
# ## 2. Data
# ### 1) Prepare characters

# %%
all_characters = string.printable
n_characters = len(all_characters)
print(all_characters)
print('num_chars = ', n_characters)
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# num_chars =  100

# %% [markdown]
# ### 2) Get text data

# %%
file = unidecode.unidecode(open('./data/shakespeare.txt').read())
file_len = len(file)
print('file_len =', file_len)
# Out:
# file_len = 1115394

# %% [markdown]
# ## 3. Functions for text processing
# ### 1) Random Chunk

# %%
def random_chunk():
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

print(random_chunk())
# Out:
# larence' death?
# Before I be convict by course of law,
# To threaten me with death is most unlawful.
# I charge you, as you hope to have redemption
# By Christ's dear blood shed for our grievous sins,
# That yo

# %% [markdown]
# ### 2) Character to tensor

# %%
def char_tensor(string):
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return Variable(tensor).cuda()

print(char_tensor('ABCdef'))
# Out:
# Variable containing:
#  36
#  37
#  38
#  13
#  14
#  15
# [torch.cuda.LongTensor of size 6 (GPU 0)]

# %% [markdown]
# ### 3) Chunk into input & label

# %%
def random_training_set():    
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %% [markdown]
# ## 3. Model & Optimizer
# ### 1) Model

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.rnn = nn.GRU(hidden_size,hidden_size,num_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
        
    
    def forward(self, input, hidden):
        out = self.encoder(input.view(1,-1))
        out,hidden = self.rnn(out,hidden)
        out = self.decoder(out.view(batch_size,-1))
        
        return out,hidden

    def init_hidden(self):
        hidden = Variable(torch.zeros(num_layers, batch_size, hidden_size)).cuda()
        return hidden
    
model = RNN(n_characters, hidden_size, n_characters, num_layers).cuda()

# %%
inp = char_tensor("A")
print(inp)
hidden = model.init_hidden()
print(hidden.size())

out,hidden = model(inp,hidden)
print(out.size())
# Out:
# Variable containing:
#  36
# [torch.cuda.LongTensor of size 1 (GPU 0)]
#
# torch.Size([1, 1, 100])
# torch.Size([1, 100])

# %% [markdown]
# ### 2) Loss & Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
loss_func = nn.CrossEntropyLoss()

# %% [markdown]
# ### 3) Test function

# %%
def test():
    start_str = "b"
    inp = char_tensor(start_str)
    hidden = model.init_hidden()
    x = inp

    print(start_str,end="")
    for i in range(200):
        output,hidden = model(x,hidden)

        output_dist = output.data.view(-1).div(0.8).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        predicted_char = all_characters[top_i]

        print(predicted_char,end="")

        x = char_tensor(predicted_char)

# %% [markdown]
# ## 4. Train

# %%
for i in range(num_epochs):
    total = char_tensor(random_chunk())
    inp = total[:-1]
    label = total[1:]
    hidden = model.init_hidden()

    loss = 0
    optimizer.zero_grad()
    for j in range(chunk_len-1):
        x  = inp[j]
        y_ = label[j]
        y,hidden = model(x,hidden)
        loss += loss_func(y,y_)

    loss.backward()
    optimizer.step()
    
    if i % 100 == 0:
        print("\n",loss/chunk_len,"\n")
        test()
        print("\n\n")
# Out:
#  Variable containing:
#  4.6094
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bC$#k9[VD0\Da(1XyH[q$D`4_utu*5J*
# =|;EDY'V
# cJ2S3\`>lmA,bL#<oii9^'Sc>BcU\H
# *Aw3>4!`RFZ<ks_z`HEm_I[e3n6ds`tZND/]	Dab{w	9k#i|O%/d<z(*aANd+WSJ2O{3im7[nC]K{F
#
#
#
#  Variable containing:
#  2.5614
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bP.y pdakO had at iare coet pa pas ses pine conn hkisisthan oo yof dores, nire he uicarl smeing tond oures eme akvest gang this murs hoon asat
# Sou thel gour he lo houc, arer th in noungelordourd you, y
#
#
#
#  Variable containing:
#  2.2744
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bug; ford wise there.
#
# QSZATEA.
# AWDKLO:
# And herere of it his he I parliog conl and'd it dor tony sith radin to bourg wings hore the mnoll patint orthe-in of ort, thame ard xull donwem wind with can tho
#
#
#
#  Variable containing:
#  2.1945
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bvese upase food sherer not in my he the cime; hind dorm,
# I cathatess not
# Thithers hav' beat lke'n thaing.
#
# BUTUT'MEN:
# ARIN
# Bith fothew the miand le ndak and thet sell;
# Yom ous someat my you hando, the
#
#
#
#  Variable containing:
#  1.9583
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bdy, tome with have me im in, you breest in loves:
# She if, wive thet lith my the bothy kere,
# What theim;ies wauch the be of but. me chat prould nown that mony,
# He my the my spelt-lly wingen bred,
# And s
#
#
#
#  Variable containing:
#  1.7867
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bry as thies soor the ihighither four preep
# is or knome deave the loot of of messe how on that onorwis,
# I sor of pory the your pienting.
#
# MPEYC Shall sing Mitio! my to on pringer,lay; Abllounter to my
#
#
#
#  Variable containing:
#  2.1942
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blw'd thecrouk scire lith as not love more wear nom whir thou for thour enter'd his, get etle me lich
# So fou the all and with the k done.
# Thest mould the then, no age smear, not he ain this morient, Tu
#
#
#
#  Variable containing:
#  1.7277
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but you hereful's weall's thene,
# And the san.
#
# FARET:
# Whis lood sure jom wach the of and in out of unds to,
# Fon sore to be sweal to the seave prited.
#
# TRAEN NOR:
# ?o hath
# And; is coun ap you broy his 'L
#
#
#
#  Variable containing:
#  2.0593
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breace thouss raute your evenst: not dither,
#
# BARINCIVO:
# I have to for lard.
#
# ROMIO:
# Nouses.
#
# LUStien: kent and word I the grou das,
# And the preall and of breatulome, the lord.
#
# ARIANLUL:
# For dous the
#
#
#
#  Variable containing:
#  1.9216
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble? for the commeth.
#
# KING IK:
# Now so the thing aman makes carigtreten.
#
# ROMES:
# Sen in my fared stany the and Lomes.
#
# GLOLINA:
# Mukes treep then I dearss,
# The right kint siment; the lord, be the lattin
#
#
#
#  Variable containing:
#  1.8537
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bouth hesened a man
# The thad am he of suppight of in you not off.
#
# LANUCET:
# Whosent purse thy shick--'moch would light have not on.
#
# SLach she will fair now theed heagh,
# Plows cole with you will of of
#
#
#
#  Variable containing:
#  1.8235
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blour were shall resturitio, but your
# And his us come my you for that be hart not with surco dost such
# But a in that the scoll be her,
# And bemons thest it in that sir deastiat;
# Whither the wher thear d
#
#
#
#  Variable containing:
#  1.9599
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ben curts,
# Hear,
# 'tave faret curpem havins, hourge dedople,
# As we that es veramess to now speat-ching be spillust his hack had shall it noced
# With your thee to sain, saye boy, beloes
# Dond'd, and but to
#
#
#
#  Variable containing:
#  1.9146
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# besse is his Carrive,
# Thou'd a so thy shem yougher's ghou ded bothing should the dowe.
#
# PETHARNO:
# Cill sirs! the eeration:
# I lind, sirrouse hid this this so a cang why live;
# To lack telp love deartelf
#
#
#
#  Variable containing:
#  1.8435
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble more sone thant his me.
#
# CTRGARED:
# And my swordgengely plook his due himing.
#
# PERYUCHINA:
# CALIO:
# Where till, you thou nor thet rid, genthant
# Be thee ais to hand the his part
# My sill had more gomend
#
#
#
#  Variable containing:
#  1.9367
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blokess:
# But thy whow God
# That do, warrin:
# That ma hath, a be gonoun bad un and and mort;
# And may do Hool re looks or dies,
# The so to soul your so blood
# Shame with and see illy so shee not it 'yst hoat
#
#
#
#  Variable containing:
#  1.9286
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bADt he havamber undul all the dise the rettur,
# Let not to sudst whine, gover me?
#
# ARCIO:
# Well to your is the stay; duscittold,
# I the have lauce some my sinver: this pife,
# All may the wife, I their str
#
#
#
#  Variable containing:
#  1.8013
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blest:
# I exay off me the ly as tlesent:
# Witrage is peperrelp eye? to rive the, so preast her
# The cans and in all deant:
# It dispeek thour my lord, of me for of thee
# Dimble with me?
#
# GLOUES VINCE:
# Thou h
#
#
#
#  Variable containing:
#  2.1206
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# boke will de mone.
#
# KING HENRY VINCENE:
# Kor the on thy life thy life:
# Hem the should gell of king not.
#
# ROMEO:
# Corts change onous with him that state his fay:
# And what sut my brown call that.
#
# KING RIC
#
#
#
#  Variable containing:
#  1.8881
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by Dity the richice,
# I my leth shem brow, one make made;
# Thou make of the donneath?
#
# FUCINIUS:
# That you skent speat, when itire unties.
#
# YORK:
# Themighter master the of thee; the wall thou came,
# Thou ca
#
#
#
#  Variable containing:
#  1.7637
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broking not agains!
#
# POMFIZABERLA:
# For for and I would alate is his son,
# The devergh again, at I make our and more to to mad
# What this in in the donong our stair;
# And to we in here to bometh coster;
# Bu
#
#
#
#  Variable containing:
#  1.5494
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# burse lows rocevends, dip praces.
# Lord?
#
# GLOUCESTO:
# Caguch but is prince an his past have the befiens?
#
# PARINE:
# Which thy peirse.
#
# JULIEL:
# I an ither's thance:
# To prough demperfison with besses in thee
#
#
#
#  Variable containing:
#  1.7182
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bate have take the seech your shall for the's to fain,
# There your may pay up cure, for case may.
#
# KING SICHARIN:
# Where, weep the him pelace not in-sorly Peasuent of the world:
# And the with fath wrarny
#
#
#
#  Variable containing:
#  1.5552
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bother in of This amchen.
# The is the feal him: dantor heal and be sir,
# And nasfily certiented brown.
# 3 YORK:
# And speat with have bant I art be froum,
# And be think whis stood gooks bear deport Were and
#
#
#
#  Variable containing:
#  1.5932
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bgan a my doons to seaving
# And owers his to here begen all stoms.
#
# NOMEO:
# You shall her; my boyess, which and that to to what you?
#
# PORKENEN:
# Comeched the not see in; and mich myself
# Brecert is father
#
#
#
#  Variable containing:
#  1.8326
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bGWhe seoth come, but no moyal on a confer.
#
# ROMEOU LONTON:
# What sin not of whest pleace shiou thing.
#
# ANGELO:
# A pring our it vitot; he not the pursese
# To being's son of 'she her hose to to we never us
#
#
#
#  Variable containing:
#  2.0332
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bNor if:
# The still not, my blood stor the heas
# Py not they may bid Torted prises, again:
# Thou and or myself Is this shall the was.
#
# MERCUTIO:
# Whace and such brown the of you rove you:
# The are your be t
#
#
#
#  Variable containing:
#  1.7123
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be sire the in that:
# A go shall neeer a dour then can't his beewards:
# Then of nothand the word, done muse of a truble
# I mould bent have to moy nopled.
#
# JULIET:
# Lond Hentlemo! blood mine in being a with
#
#
#
#  Variable containing:
#  1.6179
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bal I a worse,
# And and a more, songers the world like and 'tis one
# Thee the lods of the strulded to the moon,
# Ever to bath how that sell? Frat, we dose
# The begnain, the sir, her mach, thee, not is enec
#
#
#
#  Variable containing:
#  1.6666
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble heavess!
#
# CORANIANI:
# First make fennainst made from not, to stund it
# Which his best marshone like theat deach me the beren chouse,
# Speak, when now, what you dear like been they him
# 'Tand I your liv
#
#
#
#  Variable containing:
#  1.5446
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blespriph which he marrishal then
# I hear time he deas?
#
# SeSTawn:
# Most cossice is to death?
#
# DUCHESS:
# No he kings stand the seen!
#
# DUKE VINCENTIO:
# God go thone and say. What erest, the For it
# To king it
#
#
#
#  Variable containing:
#  1.8123
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bere peid, in will this;
# And good come in clord, lit of enconger.
#
# JULIET:
# Was it compure thou world I have but handing.
#
# BRULITA:
# And and face of as am him for thined
# Frank the will to me of graind de
#
#
#
#  Variable containing:
#  1.7902
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bods sent their bluge here,
# And remant would a with a lord, fullines? 'wite will,
# Than my chards therefut him, and this were sword do Histrects states good love;
# Jod for him it so you have a will wella
#
#
#
#  Variable containing:
#  1.7651
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bRONIO:
# Should and the begat seictors and Comed thy say.
#
# KING RIHAD:
# Your are whom he wary'd me, then us?
#
# Nurse:
# Not his have dentle were in the are have by eath
# And she tence, creath, and this book
#
#
#
#  Variable containing:
#  1.6313
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bst the have tunon brother come cass, worn our bet been
# As the states down the lord, in lived! I a would know.
#
# CORIOLANUS:
# Hin to in am thom the way brlevent be hur
# Whould is mad, the whis thy seem.
#
#
#
#
#
#  Variable containing:
#  1.7726
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble field the fold you.
#
# CORIAS:
# It live him the look all a wark?
#
# GLOUCESTER:
#
# CAPULET:
# I capply to eareding thy call tomen they
# As on us wells is my time our men pleas:
# And sir, and repose all the la
#
#
#
#  Variable containing:
#  1.7309
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bbond in of to the noble
# Sin this seems of you cance more alack me thou can my watent
# To the siet, belon and chim affear the body to
# This prince to so sour his ceers bear;
# Under lain now mean! ere time
#
#
#
#  Variable containing:
#  1.6183
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belled you?
#
# First Seeps.
# And Coul so a spent the lord:
# What wime her fall the ban made hargal fire,
# And heaver know the waral fair then
# And the suppoot a stos?
#
# DUKE VINCENTIO:
# My fand and and be solk
#
#
#
#  Variable containing:
#  1.6858
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bod'd frown. EDWher it since son with thou can in disess thank I dukes my call.
#
# QUEEN MARCA:
# But so soul life what be shame thou.
#
# QUEEN RIAS:
# I kill bat my creaty word.
#
# GRUMIO:
# My give the with houl
#
#
#
#  Variable containing:
#  1.7219
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bberigen here yourself
# The more your for do no ward they but in therefore,
# This ran of that others,--wherefore to the gone,
# For do heaven the wouse perseas,
# your for countentes with the Cloure.
#
# ROMEO:
#
#
#
#  Variable containing:
#  1.5149
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bs twigners; be Landers to peath inder hight, dear, I were it is mester uny's have hath
# If I have in this never it shall withered he:
# But dench thing thy good Kander what where bond brother;
# Ay, have n
#
#
#
#  Variable containing:
#  1.7568
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble to hath.
#
# GLOUCESTER:
# Most sin, and all the are to receary
# To consents thistrim, appy with before comman!
# When and merecought the bear, sir, with to swere henvse.
#
# First Mud:
# Sing bold thou do may.
#
#
#
#  Variable containing:
#  1.6991
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# boddess the man percit is there,
# That richers. Good chall a worse me to rights.
#
# DUKE VINCENTIO:
# Thle dewralt me this dead, hams, me your must heart
# To clove well. I the say and destrement
# Andnemen and
#
#
#
#  Variable containing:
#  1.7833
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# berits in come thereford.
# She have beave to us offers: the sin again.
# Let worm'd aftering honsor: her. Who, with and resir.
#
# Coice you pring:
# He love, have wond but dissiren'd were brown weower,
# Thou m
#
#
#
#  Variable containing:
#  1.7648
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bseld be solding time and sups
# As mine you we pererises care and to rain,
# I cath what been a partigent the love Herowrator:
# A must brother that All will now forth.
#
# MENENIUS:
# Let all comple sirry in lo
#
#
#
#  Variable containing:
#  1.4939
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# body ancay the restar,
# Thou all and that have with no lords sock'd creath and wift wives theat
# Thy fifies the man his take of mistresses.
#
# RICHARD:
# Mererford scard my what good just, chiphermen our say
#
#
#
#  Variable containing:
#  1.4819
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bbore for my lives is sholl ord,
# As not now anto me not shalt:
# What a shall me connessence your that your with thing
# What a words for one that there tell ontent.
#
# LUCIO:
# I'll comes as a bluch but of ma
#
#
#
#  Variable containing:
#  1.7571
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be and knames child
# And stooly be sons a hallond to folly:
# To lord wather him have over as seet she dups to where
# The eyes of he are vereits me here--
#
# LUCENTIO:
# What he consiest stood I'll hearth!
#
# Fi
#
#
#
#  Variable containing:
#  1.8925
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blemich their heaven
# himens of his fall against, when you part.
#
# JULIET:
# The fachore I not deach till many do unon to make me.
#
# ANGELO:
# What the more her pray watill their dangay all heart:
# Prave ronea
#
#
#
#  Variable containing:
#  1.9428
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bele for come leatire
# This mother thou arritiens and a done his.
# Making of my bear face, a come to the
# eire the blith live in tell some,
# By keep comsence; content the wan had.
#
# LADY ANNE:
# I that my fac
#
#
#
#  Variable containing:
#  1.8155
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# boondy consent.
#
# First your fearty!
# Whyself most you kingh nauss!
#
# ROMEO:
# Where, whoat is queen I bear sent him.
#
# MERCIUS:
# Which I well.
#
# VENTIUS:
# Make the wreap more groyalding doesed ager be dear
# As
#
#
#
#  Variable containing:
#  1.5882
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bellow too soor beadch lords
# They and did he'ld be despitious, Velei:
# Well; and our profsese fit rother,
# Thy weas your wather the naverow my here you better
# Brething, good may I have sir; like the fath
#
#
#
#  Variable containing:
#  1.5693
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble dost this a shall sho?
# The lide. That see arm is to the peach a purse to that of be words,
# And away by for this pray off this shalt will she.
#
# FLORESTER:
# Could now that this are tordus meace to is
#
#
#
#  Variable containing:
#  1.5362
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# both the blood, Aammertainos the dear.
#
# LEONTES:
# The tracling, which if and you, most here with me.
#
# BUCKINGHAM:
# By thine thou dies wave thine for it croyst chose.
#
# First Mance:
# Unt mattoring thy lost.
#
#
#
#  Variable containing:
#  1.7736
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bel?
#
# PRARIAN:
# Why, well his fiences cannot and enates you.
# For my lord, cannoble and prefort peace of that so
# such say than the leady and stillow;
# I creent now now fauly; sir; you and south,
# What that
#
#
#
#  Variable containing:
#  1.4673
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bodden ap
# His gawn, merded as my do my love in then were him.
#
# CORIOLANUS:
# If lettand, morn and them not warrantio, these!
# She hear he must is with she shall say and Capleas,
# Cate to are mine and to a
#
#
#
#  Variable containing:
#  1.7336
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# body as up
# The more is his stool infent grace:
# His king disclace groy him?
#
# YORK:
# Well be well. Hould is fair me, and his is desent in now
# Thou hast to do know the excap throw dispose and ladm,
# Whol he
#
#
#
#  Variable containing:
#  1.7930
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bold,
# That coarse to a love of must.
#
# MENENIUS:
# He to his provate, that will and tell;
# And my rocaly the soundst againt: your fear deary
# And busided as to hit a would comes aid; I will many you:
# 'us pr
#
#
#
#  Variable containing:
#  1.8632
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# body'dilans:
# Nor the pation me a mong to to Murquress at yours;
# And which are you face a tell we storn in anious and their lade
# At death that not thou claughternam!
#
# ROMENO:
# No a poor him of me up were
#
#
#
#  Variable containing:
#  1.5222
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# b
# Le'e in truth the come thee he would plewing speadion
# O, made, soul my lord. Where he say, friends the our
# be try of that the ould women your head their rost
# Here then stome and be it, udmance gods d
#
#
#
#  Variable containing:
#  1.6819
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble see this faeding
# Far than a am begie of kincks anca own thee?
# And my fies of the deedful, what the liberedant:
# And this knates faults the save than thy sading?
#
# SCalO:
# He to the lip offelf, in adov
#
#
#
#  Variable containing:
#  1.7626
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bothy love:
# Mrother loved me me, and his long, in the down, deast the sards
# For upon that heart dome.
#
# GLOUCESTER:
# How man,
# Were you have they so true, not id, to.
#
# DUKE VINCENTIO:
# What mark of his wor
#
#
#
#  Variable containing:
#  1.5323
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broken'd.
#
# HENRY BOLINGBROKE:
# Will will againgy that times your soul?
#
# ISABELLA:
# I have sweech thou worlend him and, the soverey?
#
# DUKE OF AUMEREL:
# Condull morn for him things, and the shall but death.
#
#
#
#  Variable containing:
#  1.8490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bratter as what,
# I seep on my counder seech.
#
# CATESBY:
# What me the vooling whet nothing
# shorland of weep is so heird bring'd;
# And I may mey lase the earthing unother as bed:
# Brave make and he frain low
#
#
#
#  Variable containing:
#  1.6992
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bess rease any hath that seak.
#
# DUKE VINCENTIO:
# If the creats to world loved in the shall believe you art with,
# What never be this farrity it heavens,
# And me shall think it son our but begon if her pea
#
#
#
#  Variable containing:
#  1.4361
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be, for fallent
# Who strangers I pation of greate and the pretucks
# And thou am disure this is the king thou gentle
# And than will prayer to should that
# I their dead, and thou soul of him my loves
# And the
#
#
#
#  Variable containing:
#  1.3267
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belf, her yet her hes he hast thee fave
# 't the wear it or far thee stand it me.
#
# KATHARINA:
# Ale ation the is the shall on not now.
#
# QUEEN ELIZABETH:
# Thee and these you do now the speak Romes
# drieve of
#
#
#
#  Variable containing:
#  1.5925
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breect and too heart.
#
# PETRUCHIO:
# My be sir, and the comphrieth the rent's but the will might;
# My the sunded to on the enty little that bear enter'd,
# Your heart is prose in him.
#
# MINOLA:
# My ment shall
#
#
#
#  Variable containing:
#  1.7312
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble chargiers,
# Such accompose time of merefore more of my lord;
# I am now lord and meince's to me;
# The many weep in me on?
#
# Belonge:
# The sill-marter the lord,
# peat is not her and combs
# Tit their do year
#
#
#
#  Variable containing:
#  1.5365
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be, should is is the make it are freem.
#
# GRUMIO:
# I will be not so, and a wold him this offeviet am worm
# To my so, the wistress intest of it speak.
#
# NORTHUMBAND:
# All think prove I'll speak have sons suf
#
#
#
#  Variable containing:
#  1.5785
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ber his Romeo, delight and better--
#
# DUCHESS:
# First a poor you have dispostor, but down,
# No, her lords he soul loot he with by to the will?
#
# TRAND:
# Greath the is their love me have be thee
# For not be v
#
#
#
#  Variable containing:
#  1.5984
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be on less thy bloody and tress
# Spevy to smoud! the son at stever;
# The good all our I mage, my lord; will bless in whire to beget
# me time with the his thou have so and should miseright.
#
# DUKE VINCENTIO
#
#
#
#  Variable containing:
#  1.7890
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bely may to your takes and the had enceffery.
#
# PAULINA:
# Lood heavens to hearts and it a tray,
# And the true the seath to than sir;
# Was that I mantion to the honour bat is for the and
# To their boody to t
#
#
#
#  Variable containing:
#  1.5420
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ber come.
#
# ROMEO:
#
# SEBHPEY:
# I'll as his platy me me know the sir, that wah'sst Ming
# Ullant in this gentlefrence here's gaughure as make the call.
#
# Nurse:
# Watch the creaver will'bs to littlift with this
#
#
#
#  Variable containing:
#  1.3429
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but, and be men not that not,
# Less, they disposain, I made, for me serve verphity
# His of husband affecter seath, and thee in
# Trammon and their succossest
# The spet what me, Custer, and stirs,
# The trief,
#
#
#
#  Variable containing:
#  1.4863
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bears on me wile my housed is with heed.
#
# MARCIUS:
# Then brack'd then me alfert, and a gail,
# Most thou had lord, in though of he from thequethey
# Whither this Comen, not I honours by heard.
# Your cofful i
#
#
#
#  Variable containing:
#  1.7668
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belat my fortune,
# By the fights the prays to shall were prople shall be
# On the provise time Harcis!
#
# BRUTUS:
# This trubrasion, piting,
# And the right affecting thy soul powers?
#
# SICINIUS:
# My laughter fro
#
#
#
#  Variable containing:
#  1.6167
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belay and my distructions born shall his nothing dispects
# Thou hang whore as whot, to mull'd hence, tere?
#
# LUCENTIUS:
# I be the would pity heart us to peacion, cordies?
#
# QUEEN ELIZABETH:
# Swears, on I me
#
#
#
#  Variable containing:
#  1.8445
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bent me; there,
# 'this before brother shorse, hin shall would prince
# Then be is eventer plainted mengest itruch are for your head's to comes all,
# When my contrity, be poises,
# And friend seet intenst, an
#
#
#
#  Variable containing:
#  1.4467
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broke our may would
# Wills shough she falsebous, for thy gold father;
# beting, by acher that in seen witester me
# Thy face is he a changers her my less,
# Were you have over! heal thou have would so,
# The fe
#
#
#
#  Variable containing:
#  1.4737
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by of my coubtion.
#
# KATHARINA:
# O then emectioat o' then for the refunt
# Uny this come wive common Romest thing.
#
# SicLO
# No: we she pead he give unnest, compone me down is not
# Take and I stray craition,
# T
#
#
#
#  Variable containing:
#  1.5958
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bjere--his will lostion,
# And that curse, that well upon childers of me:
# A to my fool, what swift, not the dear
# Stay, a burn will thine, stost! Welcome into the course
# To purces Kace you any hand, scurb
#
#
#
#  Variable containing:
#  1.3459
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bach Murderer do seer
# This ring the best! Monder he senther ring
# They see seal bear the worse stay he is a be me;
# As to stand and a purpose.
#
# GLOUCESTER:
# Come in this the bade thee to me will warse to
#
#
#
#  Variable containing:
#  1.3768
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brasure, the grave,
# Take ull thou say not me of me in baged,
# Which manion tray though we'll gods,
# I king the contently this came this arm,
# Thole man all makes sees. Wood say
# And I have takes thou what
#
#
#
#  Variable containing:
#  1.7561
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belfer the seak.
#
# Nirst:
# That chathed to his one and an upon in the leave
# to said to uncle man, and of him,
# Be roof think in these hath, I the dies vire of their prissured while o'Uet
# Take should I to
#
#
#
#  Variable containing:
#  1.3311
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by heard she till,
# The crown'd the brother befover to them.
#
# DUKE OF AULET:
# In you have our rengues to at and the belf.
#
# VOLUMNIA:
#
# CORIOLANUS:
# I say that I princess and accessineal to couse.
#
# QUEEN MA
#
#
#
#  Variable containing:
#  1.4208
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broust of them never bands on.
#
# KING RICHARD III:
# I end his camble of Bovent great,
# Of the bear much you hath, nough to do the name
# I cause the known and fast mouth the but sorrow
# The croggs. You cosse
#
#
#
#  Variable containing:
#  1.6795
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broke hand or countrans,
# If my lord, spleal right contently as and face
# To gentle her' your well thy hunged sport a come;
# Anders of his true.
#
# GLOUCESTER:
# Now he love, in a mongher breather, they dwell
#
#
#
#  Variable containing:
#  1.5063
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be, and confess, thy heaven's will be delife
# Thy for his good sail me! I maked,
# And the ear't, my transest his your fat:
# I thanks of my giver cobless, his is how here
# Thy table and in ere of his accour
#
#
#
#  Variable containing:
#  1.6915
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bed and is been and deate
# And thy happioldremans the boy, that with a mones
# Yet unto the body, defor the all this soverect too
# with thy kild the succy they,
# And daught in the treyalbes: and this eyess
#
#
#
#  Variable containing:
#  1.7574
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by here of him and your live
# That any doubly welf shall villementain strikea-day
# Shall be; man to the laster'd grown thee,
# And with the resembomed blood thou arptrich so.
#
# COMWARD:
# Rome it not to be to
#
#
#
#  Variable containing:
#  1.7362
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bele other in of
# Willing is gain'st me to my race!
#
# TRANIO:
# Now being of their were son is bed sit say
# And noble comfort enough for the body:
# By right now, gid Edward, let it, if you were us.
#
# HASTINGS
#
#
#
#  Variable containing:
#  1.6739
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bely subsle would be sword;
# Therefore no slas' been one of great?
# That thinks upon the plase but mel.
#
# Second Murderman:
# Than the ninks of they whil denence for aloves the son.
#
# FRIAR Grod I man is I t
#
#
#
#  Variable containing:
#  1.7274
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bed to daughter for
# Whom creace, cossicions you huskers by
# Whore his beg, his falso too colicenting deck'd;
# That spent his like for that to myself
# That I crown to loved in the careby not of George's fo
#
#
#
#  Variable containing:
#  1.5596
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bank in this names by at link.
# We that hands and fird the thou chearing be state,
# The cannot the sin returning for stoumn learning
# That since my make the voice let thy cans over to the
# subs away, and l
#
#
#
#  Variable containing:
#  1.5108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# boys to amones,
# How with he rage in high apperited la
# Behell, we lastion see and thy,
# The eyes all should my most less.
#
# Provost:
# Wetter, and your resided welment
# The that said you tentleng for the som
#
#
#
#  Variable containing:
#  2.2333
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# born of the procearth.
#
# First Marrmin:
# Now, fast this teet the chast my trunk at thou thy grace sell
# To creat!
#
# MENENIUS:
# Who as this he'll lerfore hamen to comfort
# But from him, and revengerer, I done
#
#
#
#  Variable containing:
#  1.4749
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be mind that are will.
#
# BENVOLIO:
# Why, are to do the she have it too takes me that that mine remend it
# To beaven to die to younged if acce of the love's on two danges me
# Alove on depardon.
#
# HORTENSIO:
#
#
#
#
#  Variable containing:
#  1.6082
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bey grear of the must the
# servelost one is be plines so that untlewle a ropet's thee,
# This is prive to be she inter short, sir,
# And since, like take my serve, belief me.
#
# JULIET:
# The more side if the l
#
#
#
#  Variable containing:
#  1.5617
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bAst it it, which him,
# As piture on your unyorr life
# Our dies the each my day, bution,
# Why, that I would your nears the have it of myself.
#
# HENRY BOLINGBROKE:
# Thee, as mine that hath that thee, I'll in
#
#
#
#  Variable containing:
#  1.3126
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bby fell think and leard that revenger in the much and me;
# And at the fettleds and be either, the love,
# That lay merrorlesting true our sumpering,
# I know is should mer, the tloing of you,
# When my pretu
#
#
#
#  Variable containing:
#  1.6010
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ber to pearent.
#
# Firse:
# He is to to to atto state readam.
#
# PETRUCHIO:
# That the please not the chasty the prince?
#
# Second Marchram:
# And him that night of Murder tods!
# Go to my mother consent, but and no
#
#
#
#  Variable containing:
#  1.4084
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belse my more must and my is the time
# I'll so, his shall sunberench, my foor adymerouth.
#
# PLUCETRANDIO:
# Hy rassion.
#
# Prate:
# The recook it hell of Cillings, and the is with
# his bold me choour with the e
#
#
#
#  Variable containing:
#  1.5799
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brew; their king.
#
# NORTHUMBERLAND:
# Nor: why prisage of the pase it mate's heart adever
# Unjury pray and your biding wrpet a fite.
#
# KING HENRY VI:
# S, the very bestard of the shall pass'd to exjurpus;
# The
#
#
#
#  Variable containing:
#  1.6513
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bent not shall be should,
# I a love of at spetweer,
# When 'we man! 'tis as of know glad away!
#
# ROMEO:
# O list this news then to my love and loves:
# On on a piery shall was stirms, and well each
# To here the
#
#
#
#  Variable containing:
#  1.4305
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beat fortuness woman much
# But sevens the know my why less,
# In the cause, and indess, or fear;
# For I will stiak of a grave her partainst else it,
# And 'tis that are with you sturn hill our now Rate, thee
#
#
#
#  Variable containing:
#  1.6144
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belivering for the great care
# My dooth a meet to soldiertion.
#
# MeMEO:
# My mothes to the nop our merrory,
# Now is Seest to do your shall and deack'd shel was
# not been death magateo, it again.
#
# LUCIO:
# Head
#
#
#
#  Variable containing:
#  1.4385
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bore, who, good wither.
#
# ROMEO:
# I will to blest your have here pration
# Not well the west what best undery there a maid they,
# And change way anto her lord! Good, go, and guilt your lage:
# an here at briv
#
#
#
#  Variable containing:
#  1.5061
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# boin my rosed thene, of the fear's
# That Allase with him fight in this head marrient
# The court to dark there, what should when him to-most?
#
# CURTIS:
# As a was meant patime this high in my heavent
# That st
#
#
#
#  Variable containing:
#  1.3510
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be been say the fame with supper, come
# Agains not thou heaving of the king,
# I may the king of haster'd he did wither!
# Herrean speak was as of Rich
# To the such lofthing of the loage love.
#
# PRINCE EDWARD
#
#
#
#  Variable containing:
#  1.4649
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# booth is of my shore sir, what
# Such keep these forth be such hares,
# What dear is a grace would the bed.
#
# VILLINA MORKENA:
# Why, there is to have king our stand framed
# never in go was have bear to say ou
#
#
#
#  Variable containing:
#  1.4934
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ban you is all a made
# world paty figh of you stray present poor to resover would
# To me the sain, but came it here seembooe;
# And I not crue to that I daughter refure a
# here I have calls write me do not
#
#
#
#  Variable containing:
#  1.7687
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bour against the walk barrwiseress
# To it so brother's call me sight.
#
# ANGELO:
# My fares hrones of your oar,
# I would be hart.
#
# GLOUCESTER:
# Your given serverish'd as envove
# Of will they coummgnorey; that
#
#
#
#  Variable containing:
#  1.9352
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bish and lean, the tords flocker world all.
#
# BIANCA:
# Ay, the harder the play, thereforly, mean be endow
# As say, sety that resited so:
# To seeting to your heard shall march to the into her recking.
#
# RICH
#
#
#
#  Variable containing:
#  1.5896
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bour, and unwas's thou man my die, and
# Come to expers me thou have should swoneth but you
# now thou then made in the cole hand of them of the mey and mine on I
# how the ragerow away bain thee rissess,
# Co
#
#
#
#  Variable containing:
#  1.4549
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brof my lord, stance and reward
# While in my new the citizens, some to mate
# And she was hand, and so to ble all some away to drong
# Or true noble? what were orbuables as
# That nurn of the fortion!
# For the
#
#
#
#  Variable containing:
#  1.5467
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble there I would no was well me thou as pershe you worsed of his common;
# Were consend my peace, her, and his pentable
# To do he well all a such hose, you both his sun make a hand.
#
# GLUMIO:
# What was wil
#
#
#
#  Variable containing:
#  1.6968
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bet that know the eres me of he
# Ter more to our shall too often to you sterse:
# Lest most beat too soldest, and bear content
# I know the can not you art had wicky her wound
# What I heard and nother the co
#
#
#
#  Variable containing:
#  1.6433
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bboy!
#
# ROMEO:
# Aw we days he do stay we the sect to the pass.
#
# KING RICHARD II:
# God they tainted were much often have condess,
# Common the our leam, though thou hast so hard;
# For the hould servant thor w
#
#
#
#  Variable containing:
#  1.4868
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breace; you conceleth
# To grinked of my but dear enrong.
#
# KATHARINA:
# On, and were thou basternace, come this him to at them no trains
# To time to be shall be but upon who such thend tert wow aviced
# As di
#
#
#
#  Variable containing:
#  1.6359
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# book here crows you.
#
# DUCHSESSIO:
# He lie you arrians is thou have sir.
# Nor, my life, hold mine to our may pose
# leake of Poctus not that is him a crate of our too malter twords,
# That my grounds and grie
#
#
#
#  Variable containing:
#  1.6475
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# b-atherers be fim, him?
#
# LADY CAPULET:
# And thou would return my barth, I am her mistrute,
# 'Tis the grace in with yourselves to to shought needs again the
# sall of my longuse sure, yet hold treith:
# Nay,
#
#
#
#  Variable containing:
#  1.5597
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bight my flower along
# to charder with should there's to off-go the may runy
# Come, and so for Rome and to eat of live
# Furt one and furch'd not the all, therefore marken,
# for I dure of my dear; you dies.
#
#
#
#  Variable containing:
#  1.5404
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble be my love, do thee,
# Had soubly al facts me to amam too begon
# Be my lord, who bear His a tell a made must
# If my entertherefatings; my less.
#
# CORIOLANUS:
# He of this a I am their heart:
# Whot a men or
#
#
#
#  Variable containing:
#  1.4477
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be all will right with me,
# As great comes the come my lord; by
# Come! he a king, the poy will behear
# To may his forth in the hours in his
# I for me, that is name to here
# In foot his child from a tribuses
#
#
#
#  Variable containing:
#  1.6248
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bose as
# I wall read wall, needs with true ould roright to me
# these given groan not denemon, what a off
# Whold us when to the tongue.
#
# KING EDWARD IV:
# When a give temple to the devindings.
#
# CAPULET:
# Let
#
#
#
#  Variable containing:
#  1.1889
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bour, I was your may well we will weight.
#
# DUKE VINCENTIO:
# The was you wouse this walling. Tyronest
# cind vilest thou nett-come,
# That I may I were by they come and young narlames,
# Throyal steigh, thy bu
#
#
#
#  Variable containing:
#  1.3404
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by canness?
#
# Sedry I sright! Along.
#
# LUCIO:
# Nay! honest dead! I days one the countent:
# How her with that even what the day, and me;
# So heart the sun.
#
# LUCIO:
# Binge me and end ears! O wretche, renor man
#
#
#
#  Variable containing:
#  1.7544
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broke stay Marle thee.
#
# ROMEO:
# Nay, bloot, sir, my was his ever were pleasure
# The fled in the enest wear in the steated hath heard
# Of comes of make plead they sur good not; but then,
# So state is there
