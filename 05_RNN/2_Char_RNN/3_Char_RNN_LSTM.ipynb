# %% [markdown]
# # Character Recurrent Neural Network
# - Mimicing Shakespeare's writing style
# - Long short-term memory(LSTM)
#
# ![alt text](./LSTM.png)

# %% [markdown]
# ## 1. Settings
# ### 1) Import required libraries

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

# %%
import unidecode
import string
import random
import re
import time, math

# %% [markdown]
# ## 2) Hyperparameter

# %%
num_epochs = 10000
print_every = 100
plot_every = 10
chunk_len = 200
embedding_size = 150
hidden_size = 100
batch_size =1
num_layers = 1
lr = 0.002

# %% [markdown]
# ## 2. Data
# ### 1) Prepare characters

# %%
all_characters = string.printable
n_characters = len(all_characters)
print(all_characters)
print('num_chars = ', n_characters)
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# num_chars =  100

# %% [markdown]
# ### 2) Get text data

# %%
file = unidecode.unidecode(open('./data/shakespeare.txt').read())
file_len = len(file)
print('file_len =', file_len)
# Out:
# file_len = 1115394

# %% [markdown]
# ## 3. Functions for text processing
# ### 1) Random Chunk

# %%
def random_chunk():
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

print(random_chunk())
# Out:
# I will marry you.
# Now, Kate, I am a husband for your turn;
# For, by this light, whereby I see thy beauty,
# Thy beauty, that doth make me like thee well,
# Thou must be married to no man but me;
# For I am he

# %% [markdown]
# ### 2) Character to tensor

# %%
def char_tensor(string):
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return Variable(tensor)#.cuda()

print(char_tensor('ABCdef'))
# Out:
# Variable containing:
#  36
#  37
#  38
#  13
#  14
#  15
# [torch.LongTensor of size 6]

# %% [markdown]
# ### 3) Chunk into input & label

# %%
def random_training_set():    
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %% [markdown]
# ## 3. Model & Optimizer
#
# ![alt text](./lstm_ex.jpg)
#
# ### 1) Model

# %%
class RNN(nn.Module):
    def __init__(self, input_size, embedding_size, hidden_size, output_size, num_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.embedding_size = embedding_size
        
        self.encoder = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.LSTM(embedding_size,hidden_size,num_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
        
    
    def forward(self, input, hidden,cell):
        out = self.encoder(input.view(batch_size,-1))
        out,(hidden,cell) = self.rnn(out,(hidden,cell))
        out = self.decoder(out.view(batch_size,-1))
        
        return out,hidden,cell

    def init_hidden(self):
          
        hidden = Variable(torch.zeros(num_layers,batch_size,hidden_size))#.cuda()
        cell = Variable(torch.zeros(num_layers,batch_size,hidden_size))#.cuda()
        
        return hidden,cell
    
model = RNN(n_characters, embedding_size, hidden_size, n_characters, num_layers)#.cuda()

# %%
inp = char_tensor("A")
print(inp)
hidden,cell = model.init_hidden()
print(hidden.size())

out,hidden,cell = model(inp,hidden,cell)
print(out.size())
# Out:
# Variable containing:
#  36
# [torch.LongTensor of size 1]
#
# torch.Size([1, 1, 100])
# torch.Size([1, 100])

# %% [markdown]
# ### 2) Loss & Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
loss_func = nn.CrossEntropyLoss()

# %% [markdown]
# ### 3) Test function

# %%
def test():
    start_str = "b"
    inp = char_tensor(start_str)
    hidden,cell = model.init_hidden()
    x = inp

    print(start_str,end="")
    for i in range(200):
        output,hidden,cell = model(x,hidden,cell)

        output_dist = output.data.view(-1).div(0.8).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        predicted_char = all_characters[top_i]

        print(predicted_char,end="")

        x = char_tensor(predicted_char)

# %% [markdown]
# ## 4. Train

# %%
for i in range(num_epochs):
    total = char_tensor(random_chunk())
    inp = total[:-1]
    label = total[1:]
    hidden,cell = model.init_hidden()

    loss = 0
    optimizer.zero_grad()
    for j in range(chunk_len-1):
        x  = inp[j]
        y_ = label[j]
        y,hidden,cell = model(x,hidden,cell)
        loss += loss_func(y,y_)

    loss.backward()
    optimizer.step()
    
    if i % 100 == 0:
        print("\n",loss/chunk_len,"\n")
        test()
        print("\n\n")
# Out:
#  Variable containing:
#  4.5685
# [torch.FloatTensor of size 1]
#
#
# bnnv!e-O!Y~pR=9	vvB22&/9oa=	M)//inn"6I!]54Sq&-gK(.%eQF	V\,Kv
# X)7%Qfj$	<h4z>&p[D*RM;;/vED>F=Xja]9-FtoA|gw<]ga_c	b:VoV':p71|_v#bHV''G5I;OgW3h>I=)PzYB$d T00QGEd\
#
#
#
#  Variable containing:
#  2.2626
# [torch.FloatTensor of size 1]
#
#
# b;Sh yel  ras is,
# : cor omy pern dratl whre kean
# shes cathd fo' hal ot ou yod indt
# ubaId bat sovoamn souO
# SC:
# Ier ith war ceat Sisd ha,
#
# Whek
#  near anth forl tatr, tou to in tod gry ou ry hat ance wcer
#
#
#
#  Variable containing:
#  2.0533
# [torch.FloatTensor of size 1]
#
#
# bens!
# al lou the prat atk yohor to byiondd I berengighend the the to bincesan, bucesald,
# Co not tt miks nou fufre thirwa, me t my I palll not that re kaensd the gof o cus brall.
# An and thing domesth yo
#
#
#
#  Variable containing:
#  2.1994
# [torch.FloatTensor of size 1]
#
#
# b in to shidisrs; ond the frelonconed, what culest to mriold becons tEato my to pure she will tit sepy this pandis for no om with ble sistruers bit renast ie worrich ficre toirn of lir
# The chot thed.
#
#
#
#
#
#  Variable containing:
#  2.0901
# [torch.FloatTensor of size 1]
#
#
# bre hous tin, ar moned, wot harith, my chor son adlise come
# get ce kine ptone willomes-Gadle momas lome angerer steres y u then thours afo mal my don fanath thoull Aighal seasper and un ast thast
# o the
#
#
#
#  Variable containing:
#  2.2561
# [torch.FloatTensor of size 1]
#
#
# bNICA and the shews the and suent Bulb.
# Brom maightires, but swall in
# And,
# What to ow to dums ur saord and hat ble Tear ain
# Let to tle sthy bay hang ene ium frey of the thead eit you cay bet's me in hu
#
#
#
#  Variable containing:
#  2.0266
# [torch.FloatTensor of size 1]
#
#
# by my the wat this ie yout laighef,
#
# ICINIA:
# I I preedurchy theath.
#
# LRAGNGARULIO:
# Mrothis a stake the soway, the of grarod freath say lande, ast wllelithe spiack
# Ben me be of If shall or your; there p
#
#
#
#  Variable containing:
#  1.9670
# [torch.FloatTensor of size 1]
#
#
# by lif jourd his the and heaks in nout is what suster of subest and that by beady and thant hand wirs nof what thit sage oft ment pourgsell gut is cood seing of quen, we this paye thacl chere songe uet
#
#
#
#  Variable containing:
#  1.9727
# [torch.FloatTensor of size 1]
#
#
# blate to he the napore,
# To that are, is and hood to bay the and these that all with?
#
# BUSIO:
# We ould, so low that it of housing, hure to fare youcher bettteres.
#
# TRORENG NRICHTABMET:
# You feach in that
#
#
#
#  Variable containing:
#  1.9775
# [torch.FloatTensor of size 1]
#
#
# be worty felly.
#
# LARexI your sanden? your sir a dose doth dutpaing in the conty nele, and with a spath we she thou she: oth my daint frake in pad.
#
# DUSE ONT:
#
# PINNG CENRIO:
#
# I HENENGULIO:
# Whoul son hee
#
#
#
#  Variable containing:
#  1.8460
# [torch.FloatTensor of size 1]
#
#
# be my baster and that therd tis your miltest I'll costis seath as coming herre-to henor's.
#
# POZAN ERCMIICHRCARD IIII:
# Wy warets form to wisher'd Agay brey
# Thaty but hast cother and mung the Crike seat
#
#
#
#  Variable containing:
#  1.9935
# [torch.FloatTensor of size 1]
#
#
# be to he say fraince
# hantriontes the for's lod im shath with sory.
#
# PAOTO:
# There frime deby father, in tithere prister ruce hat veart, bay, wew my hat wooding by and theree to wall be one of hake dow s
#
#
#
#  Variable containing:
#  1.6159
# [torch.FloatTensor of size 1]
#
#
# be fay, you for mich you bepor hacks lous the my benote thil thou of thear and!
# For do the doply looke?
#
# BARDIUS:
# And homino there on may,
# He wan dene, the worry mathin, you bloughter and you, shing ca
#
#
#
#  Variable containing:
#  1.9901
# [torch.FloatTensor of size 1]
#
#
# bangence shen the love ceiters!
# Did ploust is were?
#
# SARENCENTIA:
# Gidrock casthiaster, your wimitiesen frains monatred you reentares, was sils, sure of beat to his resome.
#
# GRIIZELLL:
# Bath pland and yo
#
#
#
#  Variable containing:
#  1.8875
# [torch.FloatTensor of size 1]
#
#
# ben! whim monest she glainsemo?
# For burt men in thy and lick jono, that it thou feling! shat his me, at fith the I ment, lave of who wach the an hen't and as marse
# And and my feal breest your and thous
#
#
#
#  Variable containing:
#  1.9571
# [torch.FloatTensor of size 1]
#
#
# bes your quire the hof heards our blate ridrence for talk to deasces in leck that the wapps vecting'd good not the land appon case lood to thight, have now as whe it quen.
#
# QUEEN OTHONG EPRDEY:
# 'And se
#
#
#
#  Variable containing:
#  2.2972
# [torch.FloatTensor of size 1]
#
#
# bly nids:
# My man fortuse whetipet howe of thal I wamberot this crom hoth you heetulery.
#
# CLAGFOT:
# The nour and my I we is way that way
# Why forcuft my live ling theath the mares not father a bonou: He i
#
#
#
#  Variable containing:
#  1.8996
# [torch.FloatTensor of size 1]
#
#
# bike, as for, were.
#
# COMIOLIO:
# Rotkils the in the all boop the teeth ronger lows,
# For thou wisty drother.
#
#
# SICHARIDICMARUS:
# Thou forther
# Or by truke teptod thou come, rembit.
#
# DUCHIO:
# To a must of wor
#
#
#
#  Variable containing:
#  2.0464
# [torch.FloatTensor of size 1]
#
#
# by, I'll not my say ponser, you have it them bresting, me burder my can wann.
#
# INGBRANTEHBRO:
# How match
# Ag men beliture din opty our renful and promightuing sond of in mith all le ore my mepliel:
# I bar
#
#
#
#  Variable containing:
#  1.8179
# [torch.FloatTensor of size 1]
#
#
# bwas her unching take offfeded then'd lie
# And bear, to the to--pale elave, I see, alelinchaly dentrue
# The not me the ret
# his comiter toss, that to to so?
#
# MENENIUS:
# We pains and the amansent, I prove t
#
#
#
#  Variable containing:
#  1.8092
# [torch.FloatTensor of size 1]
#
#
# bing
# Have a prother sheir love in you have for and the wouls the's ring,
# But more wing of then it shour sheal. What with eave have hone or and not the prove some, antister
# the march cannto hood
# Olse wi
#
#
#
#  Variable containing:
#  2.1313
# [torch.FloatTensor of size 1]
#
#
# bund?
#
# CARINTA:
# Come thewer loods off lough chorts
# He dagetrech.
#
# ONE OF OF LAUS:
# There siving and speittuy coon you'l her and tare
# the don of thought.
#
# LARTUS:
# Weram,
# What capure son. for hermant, con
#
#
#
#  Variable containing:
#  1.8506
# [torch.FloatTensor of size 1]
#
#
# bach, bout God thee telle gracest to to me the for musters hove beter to her or thy world,
# Whosing for his was stert thy was Marts!
#
# LUCIO:
# The due he sood prather.
#
# LEONTE:
# That howhle's to puretpire
#
#
#
#  Variable containing:
#  1.8834
# [torch.FloatTensor of size 1]
#
#
# bort all the hath wanss all I his strow knovifed this brungest canges a his that a seal?
#
# First soolinst
# in castle as my from thee shadist of do net keet and bake the sting that grating and no men this
#
#
#
#  Variable containing:
#  1.8695
# [torch.FloatTensor of size 1]
#
#
# ben bron is love I first groun or whan on enven are of
#  are deat
# That lave am it right in how lie your figied I betar sir, so dam,
# Who be urn all should livker men will not whimed supserince.
#
# DUCHLAND
#
#
#
#  Variable containing:
#  2.0433
# [torch.FloatTensor of size 1]
#
#
# blout wit thy so he not and the hoor so be hose not, my but speet wich he know preatred un'lt sweep a and hath neak in pillow my swen this his he one gayest, a loose oft swert tith my revence to he, th
#
#
#
#  Variable containing:
#  1.7652
# [torch.FloatTensor of size 1]
#
#
# bere, thy any wing of you mes. But I bove thou come will that costit, not state the agart Lay ham, holn that the she, with word me ly pood thee the thust way as for mink:
# And be me?
#
# FROMENE:
# The pome
#
#
#
#  Variable containing:
#  1.8794
# [torch.FloatTensor of size 1]
#
#
# be the brow in the and the's swelf tiet! I heathed compady for I the doth he
# sead Goven more pold me stretter yeen;
# selfends my do yuther a feeple mighter the himold the broth the greath my no prom orm
#
#
#
#  Variable containing:
#  1.7920
# [torch.FloatTensor of size 1]
#
#
# be to there I pranging of I intiso.
#
# PROMEO:
# Which! wat she reive, with ever.
#
# KATHARINA:
# Dy life ourter; Than to cener thy haw'd the faur lost and with thy I prance, be fair soules, where it what a wh
#
#
#
#  Variable containing:
#  2.1110
# [torch.FloatTensor of size 1]
#
#
# be such a come of which me then I her,
# What swall, the wass latper
# To but for
# haw'll, say hold your chongel asurm; ear, that three for the say thee sill for worjited loth,
# Why saled a are with it mery
#
#
#
#  Variable containing:
#  1.8929
# [torch.FloatTensor of size 1]
#
#
# be to mady
# But prong to his yough'd,
# To the dake his shall Richer, thes be thou surate as than his lives in thy the laster to cry stares
# Aswer spirang the the sees of her this thou with he with a is ma
#  Variable containing:
#  1.8060
# [torch.FloatTensor of size 1]
#
#
# be thee spell they he blisper still make he seepuly had lead me bring of
# pal weld dip we king towels,
# And agnain of the was 'the lishs toull of the reparding of we spired,
# And not Here the king of yet
#
#
#
#
#  Variable containing:
#  1.8845
# [torch.FloatTensor of size 1]
#
#
# brice my the now to spusention, sicune
# That left apon your farence,
# To to be friecle'ss the instrience,
# That the gation me haw riunce
# Is addone her chould,
# And your light, sume, the would a just the wo
#
#
#
#  Variable containing:
#  1.6200
# [torch.FloatTensor of size 1]
#
#
# ble redurs the fould my simand for this tour stbe cauch the due,
# That your we couls recey dise my camoun to that to couth sir.
#
# BRUTUS:
#
# MARIO:
# Murner more hope with whie me of in a pepturn't, Vear for
#
#
#
#  Variable containing:
#  1.6872
# [torch.FloatTensor of size 1]
#
#
# b as to me hangs houss,
# And thou encer'd Clancunce betring a kingnor, I brock the be eeve than untumnotaring in I world pargence agn me rease undead me chid be his hear taven,
# To men her I forth, I be
#
#
#
#  Variable containing:
#  2.0076
# [torch.FloatTensor of size 1]
#
#
# be that the bet the dester, lave of prong.
#
# BUKET:
# And death?
#
# GLOUCESTER:
# Brother;
# Dritter.
#
# RIUCHESS:
# Hay, that my lord thou from Geap the will with the dong thy merent,
# In pried,
# On thee I deathing
#
#
#
#
#  Variable containing:
#  1.9173
# [torch.FloatTensor of size 1]
#
#
# buight; to becentle the nit not Norcest first vine.
#
# SARENEN:
# Award a verven, with woun though a praition,
# To the mysell:
# Sate sking.
#
# RIAA ANbE VINCES:
# These the do father as dies the should though me
#
#
#
#  Variable containing:
#  1.7251
# [torch.FloatTensor of size 1]
#
#
# bation till ber with ever once tock's stow:
# But a but comple is wand beer and wither I say now'd with I impleman,
# Is lies that beitle face;
# I so not Callius of
# untrues, a with repevain as trung are? it
#
#
#
#  Variable containing:
#  1.5741
# [torch.FloatTensor of size 1]
#
#
# b accont that take and good bidoines
# To knows, whing, shen wail the keather and to at both there cornceser how his brousseam?
#
# CLARENCE:
# It when the elve
# O larefore that staint, of shich arsied,
# In thy
#
#
#
#  Variable containing:
#  1.5235
# [torch.FloatTensor of size 1]
#
#
# ber, I wore a ever are, trarge
# To not, heep him to this deter fame her it there is it,
# And it tue meam in ance come, thee, must a pleapts, were the stain all my plumisinks thou his son me:
# Beath. And n
#
#
#
#  Variable containing:
#  1.6394
# [torch.FloatTensor of size 1]
#
#
# be abunded the retiled a much scould the brajon the broth, bether you her war's brone a thee!
#
# ROMEO:
# If stil.
#
# TRANIO:
# And perire gives all wenting to the graughrore with thy
# you st the should be so
# W
#
#
#
#  Variable containing:
#  1.6778
# [torch.FloatTensor of size 1]
#
#
# ber,
# But your sain off the are to to prove goor of comes
# And the faty busher. Hersilly this lews affet in they home I wourditly her neven him, die levence, and swords not some terry, go, premine; think
#
#
#
#  Variable containing:
#  1.9108
# [torch.FloatTensor of size 1]
#
#
# bYs, will thank you some werent, I'dlest that the corse my beself,
# Hear one dai?
#
# LEONTES:
# Let cusure not
# horn,
# Kut for heard,
# See sead for is and sour manity--
# My tell, which of that so he deardnate o
#
#
#
#  Variable containing:
#  1.7103
# [torch.FloatTensor of size 1]
#
#
# bards and good my cruech good,
# Thou down are you beland?
#
# CORIOLANUEEN:
# Wett I vack'd of speant, truch the come of he thay stat, but and all that a faurtaus in the so not that some with my not our him:
#
#
#
#  Variable containing:
#  1.6647
# [torch.FloatTensor of size 1]
#
#
# be not him thigh mome it him of I death blooden brife, as of how not as not part that thou should of then to Bilnwitting in to not so bort the rest the do bed the dends, not they to moyer, him do you;
#
#
#
#  Variable containing:
#  1.9088
# [torch.FloatTensor of size 1]
#
#
# ble marrime would do your rearining frong bind by of to and king,
# And the resend;
# Well some but in I word ontly unone the leeds make forsel
# Why to in this lave no lever condal my to lings till or conde
#
#
#
#  Variable containing:
#  1.8635
# [torch.FloatTensor of size 1]
#
#
# beging dead not that's could a be race the would this crepell to was be the cast our come this praves the frorrant thee?
#
# PETRUCHIO:
# Yous?
#
# PERDITA:
# What, of Edward of my bring my love news to the torr
#
#
#
#  Variable containing:
#  1.6955
# [torch.FloatTensor of size 1]
#
#
# but crome:
# Is the done, here so more or heart not the worself.
# The heard a drang will tither you capeate, so it, there see me and the good he dreave.
#
# CORIOLANUS:
# What, and my from hims.
#
# PETRUCHIO:
# Fo
#
#
#
#  Variable containing:
#  1.8694
# [torch.FloatTensor of size 1]
#
#
# bes make your cure to mand now depelose.
#
# PETRUCHIO:
# Hath and sore, what he mys
# And shink.
#
# RICHARD III:
# We heart was not and to begoung, inyour
# before and by everch the whnilm, desenter,
# As a comes ma
#
#
#
#  Variable containing:
#  1.6961
# [torch.FloatTensor of size 1]
#
#
# be sto they love o'er in stay you, it night.
#
# KING RICHARD III:
#
# HERTENIUS:
# Rucksea if the reque lord, that is a must
# The vistie,
# That arce, that's farm;
# To back those then, to course a last'd, Loorsed
#
#
#
#  Variable containing:
#  1.9918
# [torch.FloatTensor of size 1]
#
#
# be shing to won
# wasb ghat to sit sould good where bear and thy coursie: thou fleed's to if brother as fauringmen.
#
# CLAUDIO:
# Where here so your lord, and for from thy come, by King corl: banough the sep
#
#
#
#  Variable containing:
#  1.7162
# [torch.FloatTensor of size 1]
#
#
# ber, ever your but sale to
# strour sain to mine in theret the meet with loves will the grace, gorsarests?
# Maten that than your deish.
#
# SCORIOLANUS:
# Have I would shall veriver mead's entelf I cannot you,
#
#
#
#  Variable containing:
#  1.5595
# [torch.FloatTensor of size 1]
#
#
# belon you will conlove there the foor thy sod.
#
# ANGELO:
# O all the hath and with steak the in
# Wask me that smay thou words may he stope aquest to me in thee in the ret in the bank her he as the more you
#
#
#
#  Variable containing:
#  1.7185
# [torch.FloatTensor of size 1]
#
#
# best me and wills of well me there
# Farened were and blooy, wolkind!
#
# DUKE VINCENTIO:
# Go, night was thee our good set than noterremping cume am he shalls a may mister; not the eartay voundogens,
# The swe
#
#
#
#  Variable containing:
#  1.7240
# [torch.FloatTensor of size 1]
#
#
# brows and so so oul of the blotts of with rest your not:
# Were both our morrant friends the pisio;
# Marchand him to the end
# But, where I should
# She's land adne wently was not love to his with to then:
# We
#
#
#
#  Variable containing:
#  1.7411
# [torch.FloatTensor of size 1]
#
#
# be not some true corsting cupper abook opting was not the whine thee are all,
# And purn strant brie he shourd
# Heard so from God we'd shall the death!
#
# Phe:
# Aw, whit take thought his spoks the had persen
#
#
#
#  Variable containing:
#  1.6536
# [torch.FloatTensor of size 1]
#
#
# beech the kill not thouk may his are be as I will consued be rest the wich Sirty, I wold sorrous; what I were here
# Fit as my mosed can here of the again,
# Lut deasing; was the spirfore him.
#
# KING EDWARD
#
#
#
#  Variable containing:
#  1.6980
# [torch.FloatTensor of size 1]
#
#
# but not days in again my look of the are for her's heaving his should doth this speping shin thine kill for the tome am ark un their and all greath.
#
# LUCUWICUS:
# My take asmer the god's dest semphar as
#
#
#
#  Variable containing:
#  1.5457
# [torch.FloatTensor of size 1]
#
#
# be that shall it our sorrant.
#
# THORIZEL:
# Again, and be impable as the are,
# It and force?
#
# HERMBARLAN:
# I go thy see by hear what the man him now:
# Thrich you have he wits but my sold what that sweats by
#
#
#
#  Variable containing:
#  1.8057
# [torch.FloatTensor of size 1]
#
#
# brove incubhigh thee unon and him,
# But flor o trough that me mine bes and to
# That sucenty and the marroud is will your fack, thou.
#
# LUCIO:
# Which a triffion, the lords.
#
# GLOUCESTER:
# The worthal's him he
#
#
#
#  Variable containing:
#  1.5230
# [torch.FloatTensor of size 1]
#
#
# bee hereing you sentbate a witer I'll conse that with we be to that so. Why, thou queen,
# Wentle mine witall you make got
# Have thee seed,
# And I wandly dought, for their ligh and truessal you with but in
#
#
#
#  Variable containing:
#  1.5688
# [torch.FloatTensor of size 1]
#
#
# b, and pancess thel here a prosped his lifest griarsa
# For marry as you will calless the mide thou will the stay of thou her brisal pusia dare Caustry,
# How that he wiarsured his lought thou hurds a caus
#
#
#
#  Variable containing:
#  1.7518
# [torch.FloatTensor of size 1]
#
#
# bat that mine conter with yount'd
# Than the compect-orn thou?
#
# BUSENVOLIO:
# He round thou struen it to by to chider sweet molling the chart eres:
# My more not, it a durity,
# There my guilath.
#
# CORIOLANUS:
#
#
#
#
#  Variable containing:
#  1.5898
# [torch.FloatTensor of size 1]
#
#
# bur, a daughter awondly of this Jove with be or you dest I our whine shest nothing.
#
# HERMIONE:
# Nor thee his
# sout Burther that nothing will distreat: men me the revenctow be blagg bout affainle thought
#
#
#
#  Variable containing:
#  1.1486
# [torch.FloatTensor of size 1]
#
#
# batience: me lost are low me brevinest of
# More not death our pase the gracy.
#
# MENENIO:
# What not slouls and more
# Mine compent-againted a fear the grast the guithem
# As my goods make are let meand his bot
#
#
#
#  Variable containing:
#  1.7038
# [torch.FloatTensor of size 1]
#
#
# bewall, my speep, the bonour for the strmancoun
# The eartake I wasce is these the staighs your sender
# To my so, a then shall the cores!
#
# ORTENS:
# The, where been unembrake no more tost be,
# The pade my sh
#
#
#
#  Variable containing:
#  1.8878
# [torch.FloatTensor of size 1]
#
#
# bat the worstowneth-the fear no take the worles'd is no There I warry, time, tell with begsied at parge more thear his so tell,
# And the did it lots honer the better? Dit thou warrys.
# That eyery.
#
# GLOUC
#
#
#
#  Variable containing:
#  1.7203
# [torch.FloatTensor of size 1]
#
#
# bance is.
# This provay hil of that die that hall and come my have and by stried the
# stare.
#
# ANTONIO:
# For you bear the duke him for betime; and to men,
# That I me.
#
# DUCHESS OF YORK:
# And the worst rest tha
#
#
#
#  Variable containing:
#  1.6340
# [torch.FloatTensor of size 1]
#
#
# bence all heart deservite
# The keased but up; for night to then a lady in is that advong his fathers.
# Here speak theed grantanty fair own hight gills the ward!
# Now againce, this but what gracter, my lov
#
#
#
#  Variable containing:
#  1.5522
# [torch.FloatTensor of size 1]
#
#
# be love
# Bucil to come ence dour slagd who long of the strais,
# That hope,
# In may you are the pevers; thee father,
# And to me with him good a cuproses in my look, I pray, and he call he are this to you Ma
#
#
#
#  Variable containing:
#  1.7078
# [torch.FloatTensor of size 1]
#
#
# beath; I know be ending comanss! I by the for thou was the good dimbererent thou alls. And a porse not bear put mold
# As, his king are the largar brought of the king peally.
#
# QUEEN ELIZABETH:
# And a damb
#
#
#
#  Variable containing:
#  1.5731
# [torch.FloatTensor of size 1]
#
#
# behal do conters in in to conforce in les shall deeen that sast and thereo?
#
# COMIONES:
# The vere, I some to him other prays mine eness the word, you know that thou that doth here and dost, no, gall are
#
#
#
#  Variable containing:
#  1.7019
# [torch.FloatTensor of size 1]
#
#
# bind to thy hister been but we bore the with so but rised on how dease wad to were't the courthers they ling his friend son to be never not with watest whall a night me the cearmy
# of in thou sores here
#
#
#
#  Variable containing:
#  1.7803
# [torch.FloatTensor of size 1]
#
#
# bethear but compy one you, I before that he am the houds, you as, be of conmench, grite the be as most take you this well to my gake that my day of out and youl's with me of them from the so will of wh
#
#
#
#  Variable containing:
#  1.6386
# [torch.FloatTensor of size 1]
#
#
# bue beas, a head, never thinger pleople, and, her as rear so'er me and I have null me sland, what sorrow, and of here's son of here's live a still the each the but say than tent pours liant to neight,
#
#
#
#  Variable containing:
#  1.8921
# [torch.FloatTensor of size 1]
#
#
# bat well so thoughts and he bather of the heaps breather my fits one fure the bray us your with we subber bless.
#
# POMEO:
# Come. Here says the king I hearth,
# That oursed.
#
# KING HENRY OVIDIUS:
# Go mistrefo
#
#
#
#  Variable containing:
#  1.6238
# [torch.FloatTensor of size 1]
#
#
# bances me the hose a kingly be spardine
# The sais in this will not bright.
#
# WARWICK:
# I will knowfel:
# And so that thoughth on threick of our ones should I will posty old agar, go with I may persadin.
# Hav
#
#
#
#  Variable containing:
#  1.4724
# [torch.FloatTensor of size 1]
#
#
# be till me with set, therefore in you more granter where's hind as the warchast of that when in my herion,
# Thou shand:
# Where you change?
#
# First CLIFFARD:
# Yet hereision and of appook, herewarty to helpl
#
#
#
#  Variable containing:
#  1.7847
# [torch.FloatTensor of size 1]
#
#
# be the toing of the wook his gave meaving the charge; love it best with I had I see
# Kill: we jemand,
# And a way, wish the
# the will upon best to on me: your though all prove upon a pastior,
# For with marr
#
#
#
#  Variable containing:
#  1.7798
# [torch.FloatTensor of size 1]
#
#
# best it' chart of myself covery hay will
# Uwenly but life, distlaint-maning excounce to the couse the rack?
#
# QUEEN ELIZABETH:
#
# Wherry would have borthing of of the are to my larcious lies and saition be
#
#
#
#  Variable containing:
#  1.6594
# [torch.FloatTensor of size 1]
#
#
# ber to him?
#
# KING RICHARD III:
# Come! Mail slaim,
# Sol,
# And with thy lords.
# If I have upon a be propeth be be to this be not like on do queen him a garks thy friends,
# That the spokest the stodness on her
#
#
#
#  Variable containing:
#  1.6975
# [torch.FloatTensor of size 1]
#
#
# bes? covered old!
#
# QUEEN LENTIO:
# O youth my best pation,
# When love, my would reard in a swould be comand,
# Be prive is to light!
# Merume is and will man by an'd with have she soon
# Thought them, made thei
#
#
#
#  Variable containing:
#  2.0454
# [torch.FloatTensor of size 1]
#
#
# be: be wash'd grice showle face, or as the lord?
# Here the remience be sir, and of in thee in burife;
# You darmour ascion,
# And how you nend shall thou dato book?
#
# SAPTIUS:
# May of and tell for-pluced thou
#
#
#
#  Variable containing:
#  1.7690
# [torch.FloatTensor of size 1]
#
#
# bay.
#
# PETRUCHIO:
# Who made me of his is no pritemoot.
#
# CORIOLANUS:
# Why the scrace, go prespersise, all thing tenderly last the true her the better on! is
# tweeps of this siny!
# Where, me to by helmens rev
#
#
#
#  Variable containing:
#  1.7537
# [torch.FloatTensor of size 1]
#
#
# be that reweet it!
# Sin hath of you.
#
# LEONTES:
# Herefore hand was much with thee 'too we may beatless aid your lord,
# And thee mine me.
# Condeen! are this to dears to myself was the perchich's lord, time t
#
#
#
#  Variable containing:
#  1.5727
# [torch.FloatTensor of size 1]
#
#
# be we promed but menten him?
#
# FLORIZEL:
# It hurthers our some were the jesorreaded.
#
# KING HENRY LINCE:
# I shis into parts, speens mine mather to my kiccush in the be his proid,
# Which her flow his pricius
#
#
#
#  Variable containing:
#  1.6731
# [torch.FloatTensor of size 1]
#
#
# be his say, what then of this play upon one in her, o' me sight his bight,
# I our pating have before comming the duith of is sumpon mellain must can that light, cammy eartion out men's pead, my made in
#
#
#
#  Variable containing:
#  1.6348
# [torch.FloatTensor of size 1]
#
#
# better the roping:
# By you, now, good were a joy'd though's pold lord.
#
# GREMIO:
# Hark upto to were hoise or me her comes are could,
# But we hord to the hollanger of lord
# Of of much deather's done and coms
#
#
#
#  Variable containing:
#  1.4063
# [torch.FloatTensor of size 1]
#
#
# balth
# Marker a not if I dessition what see, will beart the king you head me?
#
# FLORIZEL:
# This is vairitiest
# the duke of you shall steet.
#
# Calls friar aboon very king,
# Aler blood frangs.
#
# JULIET:
# Herefor
#
#
#
#  Variable containing:
#  1.8432
# [torch.FloatTensor of size 1]
#
#
# bets: if seven must lord
# an graves enough on my lord decelorn.
#
# KING RICHARD III:
# Well, sir, now strinks, heaven do him. God of that not be brothers the chanks at than fay liesty
# sine to shall had see
#
#
#
#
#  Variable containing:
#  1.5392
# [torch.FloatTensor of size 1]
#
#
# bentage for of love,
# But hantle thoushand like by base I do tears of him not that you punite.
#
# GLOUCESTER:
# No thou wemple, and my for when: I prespere on his must by let me the shoudd the trame our lif
#
#
#
#  Variable containing:
#  1.3406
# [torch.FloatTensor of size 1]
#
#
# be-dishard of you not the corroms,
# Wast not a take still in that is they bread! what abund stilligard; I death the crown this by your price; and been.
# Thank the father thank you: no dover's earld thee;
#
#
#
#  Variable containing:
#  1.6334
# [torch.FloatTensor of size 1]
#
#
# be he seed
# A vonious and the can and when wear mine and shall bear would in the paties the condent,
# And thy father, trial the good him,
# An a time will the sory and comporn the stranced me of no to my l
#
#
#
#  Variable containing:
#  1.7482
# [torch.FloatTensor of size 1]
#
#
# bind baked was Hence can unot heel.
#
# ANGELO:
# Uncweep some promband the with thee of hings and kept not bose chance bord,'
# By the disstands untenstly to his may you, Kather in the
# some, when for beinger
#
#
#
#  Variable containing:
#  1.3370
# [torch.FloatTensor of size 1]
#
#
# be counter and whore follish? Peritiest?
# If you threedander you with these of more own you one this,
# a pighal, anger the priceng of your houd is is wound
# A blood, for the stranger.
#
# KING HENRY VII:
# O,
#
#
#
#  Variable containing:
#  1.9535
# [torch.FloatTensor of size 1]
#
#
# beford be them for that heel before,
# Let still all my lord,
# A sclow my ruch then, gentless will come to the sly master yarch retiseous in hurself
# He could comforfious that
# with he so ma word, the last
#
#
#
#  Variable containing:
#  1.6041
# [torch.FloatTensor of size 1]
#
#
# be timany.
#
# BRUTUS:
# No londer.
#
# KING HENRY VICLANDO:
# Hall of Engrom of that insack the to but daughter Rickle to shall on this sucher stranst gentle shin me so but stray,
# I wonter alond are recrowns he
#
#
#
#  Variable containing:
#  1.3502
# [torch.FloatTensor of size 1]
#
#
# browed the durst
# 'tis brothe a prething and them, are,
# Besire by thy lived, plucked it by daughterty:
# Well.
#
# DUKE OF YORK:
# Yet iptoisinour said and your poopless, them
# I haves and triuh you be say the
#
#
#
#  Variable containing:
#  1.5767
# [torch.FloatTensor of size 1]
#
#
# by his drate, mar, be him we disple, to myself,
# To cannot what not the mastise, boy, that libe, you, life, what surre thee, no, what with precusing them and is flind brook be tost,
# To that make me, and
#
#
#
#  Variable containing:
#  1.5381
# [torch.FloatTensor of size 1]
#
#
# be with; I have the bake, and a blood,
# My may of him, born this a have the being,
# And sweet you corsed hear to you come!
#
# ANTIGONUS:
# O, therefold all not a wornd you will I'll be not Lord, 'to but your
#
#
#
#  Variable containing:
#  1.7015
# [torch.FloatTensor of size 1]
#
#
# beek,
# Take an hath him than to the breasing of Glody a caunter, for he taken,
# I am Edwardshy love, and you siger his life to make thereing.
#
# PROMEO:
# I to low; I decrounds as not and deace poly.
#
# FORTIO
#
#
#
#  Variable containing:
#  1.5811
# [torch.FloatTensor of size 1]
#
#
# ber,
# Is not the sight in the standy sold Here 'lilse?
# Distle no't, what not the bot, with but his lie.
#
# PETRUCHIO:
# My creck, trease not hows for I was lord to me heart to this like repores, cannot and
#
#
#
#  Variable containing:
#  1.5926
# [torch.FloatTensor of size 1]
#
#
# but can on a change.
#
# PAULINA:
# I death you sir is comeom thee.
#
# SEBATRY:
# What shame, good were if young.
#
# KING RICHARD Is:
# I is the preselo, but, flight thee.
#
# CORIOLANUS:
# Come thy will to this this fr
#
#
#
#  Variable containing:
#  1.5711
# [torch.FloatTensor of size 1]
#
#
# be
# That well, sir; our shall goverent: you,
# Unfor we changel, sore, I
# To the found.
# But, that was cousind as mine we death.
# Thou lord,
# Your hope she is
# Hast they she exping the lie,
# As Siset and him-fe
#
#
#
#  Variable containing:
#  1.6049
# [torch.FloatTensor of size 1]
#
#
# bing courders,
# Where speed, my lots be so thee.
#
# ARIEL:
# I casming o' thou will how in the died,
# When his to Plancuhing the some welces should deep to they give be here.
#
# First Hen, you are his lodd up,
#
#
#
#  Variable containing:
#  1.7830
# [torch.FloatTensor of size 1]
#
#
# bather.
#
# KATHARINA:
# Now, you a prefore peeding,
# To else in well not and here is fatheriay, sichompthenge.
#
# HASTINGS:
# You silve;
# I shame! 'Tis you as these lay
# And thou one Lome of the would to Claillow
#
#
#
#  Variable containing:
#  1.3820
# [torch.FloatTensor of size 1]
#
#
# brove the footh,
# Thoughted earth me me for all thee of the know I am roped and upan,
# And how most thou ond onasel
# For your blows, them done as friends your Jesence to have men; but conceiving as your s
#
#
#
#  Variable containing:
#  1.5521
# [torch.FloatTensor of size 1]
#
#
# bear;
# I shall thine do soul scals thy till things.
#
# PRINCE EDWARD:
# In see to the fight that sweech own and with peath this both
# Alon his be advicts loogor'd las'd our hear'd like to yourself,
# And now s
#
#
#
#  Variable containing:
#  1.9757
# [torch.FloatTensor of size 1]
#
#
# be thou canteans of change, unders and deast father's should keens he is this intalse.
#
# KING RICHARD III:
# The reafiness to it was they longing eilland;
# The thought he she purpose fold this witis
# come,
#
#
#
#  Variable containing:
#  1.7800
# [torch.FloatTensor of size 1]
#
#
# be moke the depitory;
# Thine to the speed for the trulst
# I spenation it to call of thy leasurate and lost to must matting the rody too.
#
# CATLOSSE:
# Anoted moof everds?
#
# HENRY II:
# He know the mistress of
#
#
#
#  Variable containing:
#  1.6472
# [torch.FloatTensor of size 1]
#
#
# be the true
# He with and hound at that be your so, as more son.
#
# DOPERO:
# Them mea, trust the seeved come perficerly deerrouble,
# A vaint treation country that their vorture;
# That them is more and if her
#
#
#
#  Variable containing:
#  1.7519
# [torch.FloatTensor of size 1]
#
#
# be upon but the ingear of him.
#
# KING RICHARD II:
# Ay, not,
# And the hard's scalt to wneil be face them,
# And lose my trifter peast shall glance bear,
# Banisher of that the curse, and hath expery,
# The never
#
#
#
#  Variable containing:
#  1.5720
# [torch.FloatTensor of size 1]
#
#
# bhe hown, and the live
# The are the bear and is not daughter'd in alters, he serfords,
# The do the rehen thee stais
# By out prisune, I.
# Plase of the roest. where, and that Mose
# More that connemen to been
#
#
#
#  Variable containing:
#  1.7100
# [torch.FloatTensor of size 1]
#
#
# bat who tale heavers you mattery will let
# clifing of and that may new, in him more thank's not, good thy may
# Be make grave to moke him.
#
# BRUTUS:
# What I come and part bongsia, more of old with
# And sweet
#
#
#
#  Variable containing:
#  1.5600
# [torch.FloatTensor of size 1]
#
#
# be have the bandament.
#
# CAMILLO:
# Besire, but so pursing child; now grace my have where victife by his mander surge.
#
# Second Mucire and Grave to that this shall be but your fetch the chiect,
# That this p
#
#
#
#  Variable containing:
#  1.8787
# [torch.FloatTensor of size 1]
#
#
# by vire on sit;
# And be it full so lazed in good to the cannot
# Of with the garing as in the's the give's sol,
# For leight me saint accephouf Riching good seems and back with my sights;
# Which sea, if you
#
#
#
#  Variable containing:
#  1.6330
# [torch.FloatTensor of size 1]
#
#
# by struching be fortubly, sory.
#
# SALIS:
# Who the did this like,
# And I good one hour, becious, and then which news to seem to to the not that
# it speak: thy course to thy hope that ral I worsting no tribl
#
#
#
#  Variable containing:
#  1.5751
# [torch.FloatTensor of size 1]
#
#
# bece.
#
# BAPTISTA:
# Shapery a veratten upon thereforedom foul and dead
# Is and things, eveth, all a hatters;
# That not,' with as you sever sock a must
# Whose life a head it is not, were cause
# Wrepticly will
#
#
#
#  Variable containing:
#  1.5338
# [torch.FloatTensor of size 1]
#
#
# breed's call of then and wine you will wann
# thy should father? I am will thy done he in you:
# The dire the Duke how, such dautes, I moded?
#
# MENENIUS:
# The dout not-leady, thy are tell; and his need of hi
#
#
#
#  Variable containing:
#  1.5640
# [torch.FloatTensor of size 1]
#
#
# be to an it and in
# the out the and scatter hath things, out to the mind you,
# 'Tis plain in the king your to suddest
# That saint that and not you, my lord friars as body
# That is no't did thou drey exward
#
#
#
#  Variable containing:
#  1.7344
# [torch.FloatTensor of size 1]
#
#
# be the carcher to the dares the mortion.
# She such not live.
# Which his compan'd shall bear not it,
# Is fair daughter of them, Gause your lord,
# As the fall at out this say my for this worse,
# Caid tell ple
#
#
#
#  Variable containing:
#  1.5292
# [torch.FloatTensor of size 1]
#
#
# ble a right
# So friate thy monescomes the means hate, or it come
# To the gllad part hord her as not, I prope.
#
# Sold:
# If do not the rone, these oftem death;
# For me they son, Katurally desperous change wit
#
#
#
#  Variable containing:
#  1.6266
# [torch.FloatTensor of size 1]
#
#
# believe mine while
# To you have I desers shall hoal not a mand him
# to reary hords.
#
# First Lettant:
#
# Provost:
# I have her speak and parlore:
# And wholself not you did for the father brin.
#
# RORENA:
# Where he
#  Variable containing:
#  1.4193
# [torch.FloatTensor of size 1]
#
#
# be not, but need
# That bring the preised thy fale, I way not her and him
# curposed my lord it from here now, patenous, adny
# Thou do the mause. I have so joy?
#
# ESCALUS:
# I kneaven of your castle to such sp
#
#
#
#  Variable containing:
#  1.8585
# [torch.FloatTensor of size 1]
#
#
# bed
# O, then I have that rast I will may his like to born my blood,
# In hand in the misures stand life, I will greaf all!
# How he too say, my man and that, well
# In princes it it or compled
# Camposinaning f
#
#
#
#  Variable containing:
#  1.6970
# [torch.FloatTensor of size 1]
#
#
# bent
# Yet too let wear that he do all of myself with gaves therefore:
# What shall be love that call you warness for it.
#
# WARWICK:
# My love honour rest dead,
#
# LEONTES:
# I as Mistree south. What's they sweet
#
#
#
#  Variable containing:
#  1.5052
# [torch.FloatTensor of size 1]
#
#
# batlebless with my day.
#
# ANGELO:
# God, my lord, gentince, so heaven of hid
# And ye bow the hollain she head show.
#
# BALTHASAS:
# Aloding the deast me wapes faught's mother:
# I hand shall her I have not the b
#
#
#
#  Variable containing:
#  1.6384
# [torch.FloatTensor of size 1]
#
#
# bats your of marrior gooling allmand
# Sir gentlemently sole speak us and hearn I shere my forgal how as
# thou cannot the quach furterates ever the like here all not be sulfarly,
# And the insweet, in his m
#
#
#
#  Variable containing:
#  1.6318
# [torch.FloatTensor of size 1]
#
#
# be have elterful blody of Richer'st withing to as the reast
# I father and be his sund equal all thy reas tear'tience.
#
# LADY ANNE:
# My lord; a pardon a longy
# The know eyes the to make a retished to glant
#
#
#
#
#  Variable containing:
#  1.6917
# [torch.FloatTensor of size 1]
#
#
# bbat to shall to the eart;
# Should hast scold my row they he is a childrem,
# Or imber, brave to me wor: is off this forter sorewell.
#
# JULIET:
# Good been Every shall have advoustage me for your groply.
#
# CL
#
#
#
#  Variable containing:
#  1.5669
# [torch.FloatTensor of size 1]
#
#
# be have son your shalt stimiter all yours?
#
# MENENRIURGAS:
# Now there it aginger,
# And start's entage, a feel and joince him of Lucks,
# There the stritians in they son me.
#
# QUEEN ELIZABETH:
# My house evern'
#
#
#
#  Variable containing:
#  1.6038
# [torch.FloatTensor of size 1]
#
#
# bat what welcome the been
# Should not uncate om a fettence here:
# To Romeo?
#
# Second Had and provise this a should backs,
# Which the kind 'other.
#
# From Clicest. Caty warry:
# My soul had the poolly
# Even cont
#
#
#
#  Variable containing:
#  1.5404
# [torch.FloatTensor of size 1]
#
#
# be for thou think all you
# for drumbours, one dead him do!
# Therefore now death a glory with to must of in man.
#
# BAPTISTA:
# Why, nor him that let that inteal joy graie speasted all to he wirm.
#
# CORIOLANUS
#
#
#
#  Variable containing:
#  1.4884
# [torch.FloatTensor of size 1]
#
#
# be the death.
#
# VIRGARET:
# Come, I have honie me the prisel; for bless and soul sume,
# I should had soress to do the purpones: he good so see;
# By breather honour'd, she mide, him have you do it more them
#
#
#
#  Variable containing:
#  1.3389
# [torch.FloatTensor of size 1]
#
#
# be ear the see his king,
# Who perchisipless; is make my ears:
# Is that I wear out are the greace!
#
# Provost:
# Ah, what was place and dear thus bagas
# I have he had the countain an Romeo, thou, man her,
# Was
#
#
#
#  Variable containing:
#  1.3157
# [torch.FloatTensor of size 1]
#
#
# ben a penture thou could not
# So gant eart: it and hear, boy onleed,
#
# Provost:
# And be no him take: my throne of thy king's lord;
# And thus ontimpted in own old, this in my heardity,
# To heart Pray your ho
#
#
#
#  Variable containing:
#  1.6549
# [torch.FloatTensor of size 1]
#
#
# behold I say!
#
# SICINIUS:
# To loish, a are he not swert shide is will stabe.
#
# KING EDWARD IV:
# I know, foolo, a peason
# To take in you that's a venat boot down,
# For I parting sight my bolous? which every o
#
#
#
#  Variable containing:
#  1.3580
# [torch.FloatTensor of size 1]
#
#
# bbedtin this trial your bodies me the of his
# words, and be three this love to be that from the vifience
# In innow to him our unisby Jove us the eeper know conser.
# If you no dusch'd of virty.
#
# SICINIUS:
#
#
#
#
#  Variable containing:
#  1.4138
# [torch.FloatTensor of size 1]
#
#
# be not Nay and sedior too vale the prison;
# Is it joy's care! what I did on ever
# With the is a did must dreadite,
# Still all your life an downs;
# Than none to they say, where falt
# weels no shame brauve to
#
#
#
#  Variable containing:
#  1.4986
# [torch.FloatTensor of size 1]
#
#
# by, your sond? Fornting have as beason
# countery, and in but force, lords, sore again:
# Nay, what they are done, good by my with my pits,
# And when have not did and here.
#
# WARWICK:
# No.
#
# ANGELO:
# If is in s
#
#
#
#  Variable containing:
#  1.1294
# [torch.FloatTensor of size 1]
#
#
# bear I as you know I
# That have King and my in the entrue with.
#
# KING EDWARD IV:
# Most Edward's shall spess: you fortune.
#
# POMPEY:
# A pitions to besilen to How'dess is any dain'd much as mes to Henry.
#
# PO
#
#
#
#  Variable containing:
#  1.8740
# [torch.FloatTensor of size 1]
#
#
# bast your old.
#
# CORIOLANUS:
# Now for your make brought is not the piting be to the face
# thou conquear him, my like the prove him as wan
# very a fair accuse the lord?
#
# KING EDWARD IV:
# Sweet it toch me sof
#
#
#
#  Variable containing:
#  1.3409
# [torch.FloatTensor of size 1]
#
#
# bsan,
# Mader King shore a fathers, more the such
# See is not this princess, and this so cheeked no.
#
# COMINIUS:
# He is straised from prothed to the shall stay say
# And dest devour'd full comess tears,
# I'll
#
#
#
#  Variable containing:
#  1.5316
# [torch.FloatTensor of size 1]
#
#
# by, my smigpores flor's soul's begar;
# And hear shand that my nor my arth,
# For had as wist the vow my lords best to our frantio,
# Are by father in as it where's not be not high since to heavent this spea
#
#
#
#  Variable containing:
#  1.7633
# [torch.FloatTensor of size 1]
#
#
# beth free,
# Whichlen it morn my life will his
# sorred me brother grangmen how my now this know the duke the in have will
# That have made this dutly but part to the must thou will the'er.
# I pray the body's
#
#
#
#  Variable containing:
#  1.4448
# [torch.FloatTensor of size 1]
#
#
# be forselves,
# And on ourself thou stapmouthes he wind, sir, now,
# That sweet how chood the pay
# They, would be detter the netched were a from his ence!
#
# Lady, me we art Lord.
#
# BIANCA:
# So lows, her talk!
#
#
#
#  Variable containing:
#  1.7243
# [torch.FloatTensor of size 1]
#
#
# be that march.
#
# Braking take elim the pryforture Tyrant obed
# You are at the arms and inkave for become the Heaver:
# Are change it wale play the wornot as him--braver's are thee,
# And make be that with th
#
#
#
#  Variable containing:
#  1.3259
# [torch.FloatTensor of size 1]
#
#
# be is agains so.
#
# MOPSA:
# The mon; and wronging me, or great from the gone,
# So for your deed, may good like thy lover sweet thy will
# is his is merder the crown cann a this leave she wordrman with hourd
#
#
#
#  Variable containing:
#  1.5085
# [torch.FloatTensor of size 1]
#
#
# be son
# And thee the time of my so worthy boy
# So both to baging piedres with a blood use my lughtery.
#
# KING HENRY VI:
# I was not see him not noble take my kins the queen to this look.
#
# CAPULET:
# Thou to a
#
#
#
#  Variable containing:
#  1.3884
# [torch.FloatTensor of size 1]
#
#
# breadal:
# Which one: I have the blows that is that thee,
# And thou grace path and finger morours:
# And this faced, everain,
# O dether, these precorfort,
# Which the sight with for distroses,
# But 'tis sondmy
#
#
#
#  Variable containing:
#  1.4394
# [torch.FloatTensor of size 1]
#
#
# bat of your gentle heart
# And him. That you sold and make, I I beggased bed,
# And hey entertuam eye the hold been not bring my rood.
#
# LUCENTIO:
# I may I may, yet like though messies well?
#
# LUCIO:
# Who ther
#
#
#
#  Variable containing:
#  1.7589
# [torch.FloatTensor of size 1]
#
#
# blook-so there to Your in perssied to me.
#
# TYBANDELLLA:
# Even them wither in the best of you.
#
# COMINIUS:
# I too now, so all the give I am the freen:
# But Sirry you have the vily but to arks take so hath t
#
#
#
#  Variable containing:
#  2.0105
# [torch.FloatTensor of size 1]
#
#
# by sice was nothing the life and it;
# Who self and recoul,
# What thou shalt daughters! I'll sparent to thou be sea frombandied.
#
# CLAUDIO:
# What be sound to lies,
# He is not one deam
# The poper'd thee art ne
#
#
#
#  Variable containing:
#  1.3046
# [torch.FloatTensor of size 1]
#
#
# bspeaty, and become it?
#
# YORK:
# I worst the tale o' the was acpince.
#
# First Lord:
# The kind and in and seem, brother this satish.
#
# ARIANA:
# I what date, and strails any and know him in me sess
# And the wee
#
#
#
#  Variable containing:
#  2.2589
# [torch.FloatTensor of size 1]
#
#
# best more trike of your keep
#
# CAPULET:
# Who, sight the peers? That stept,
# The choops sinesty far alone would tell hear spoin
# Amen the bloodant me is the son, what besands well hot
# do thou do brine.
#
# CLA
#
#
#
#  Variable containing:
#  1.6640
# [torch.FloatTensor of size 1]
#
#
# but our countries.
#
# LAUDIO:
# And treats a blood forior for thee,
# The dare a cannot remes thenclence to then,
# And her look agot son, sure hands.
#
# DUKE VINCENTIO:
# I sweet that I say she but is no like
# Ire
#
#
#
#  Variable containing:
#  1.3390
# [torch.FloatTensor of size 1]
#
#
# bats, and
# the may are stins see you gried: our man
# Dar; when this think are strong in his tion, give so the man
# hat I so I have I have are your grow.
#
# KING RICHARD II:
# Ah, the inlays the joyal our hang
#
#
#
#  Variable containing:
#  1.5742
# [torch.FloatTensor of size 1]
#
#
# bed strange.
#
# CAMILLO:
# This not not command to you.
#
# PERDYCY:
# I lord a dave lay in us;
# Our lame, sir, the master feel on the criel.
# Take knight take a gries to let.
#
# God he may regal, and cut father te
#
#
#
#  Variable containing:
#  1.7735
# [torch.FloatTensor of size 1]
#
#
# be by my reather,
# Beneight my love, you by placcelless out eate
# of still and hand from the fears, and forth bory my fair to chap'st thee some
# Prewell, that he gady upon the art bid.
#
# LUCIO:
# But never t
#
#
#
#  Variable containing:
#  1.5187
# [torch.FloatTensor of size 1]
#
#
# bORD II stright shall be no men think, at I have the shall for the marble enterss of my fear of Frence.
#
# CLARENCE:
# When I with speaken deast Cairtering more of you see is peerous allaberon?
#
# KING RICHA
#
#
#
#  Variable containing:
#  1.4868
# [torch.FloatTensor of size 1]
#
#
# bOR
# But that the please deport the hantard stenttering,
# Had by born with the more to the worth the field athing
# Upon them likes, I say way, the ascave an Marry,
# With Plivent of thou gentlemy mark his b
#
#
#
#  Variable containing:
#  1.5681
# [torch.FloatTensor of size 1]
#
#
# but be to rither of gaisune.
#
# VOLUMNIA:
# That you shall se's and lord it so he have
# With, and, yet it is no shall appey:
# The men hence with it to the should cause, I am the
# was on him, he soicion of a d
#
#
#
#  Variable containing:
#  1.4702
# [torch.FloatTensor of size 1]
#
#
# but his bive a fareward feerled;
# Nor know your fine of him: curse at my both.
#
# MENENIUS:
# I crues confer of this men to my soice will be
# I pressence of thy thing and say,
# Anderth help what your will dee
#
#
#
#  Variable containing:
#  1.5911
# [torch.FloatTensor of size 1]
#
#
# b.
# But we made me, and therehal light, let a man,
# Where have forch'd the noble lept me true is say.
# If presence body kind a ground from thee, well.
# But went man king revill.
#
# CAMILLO:
# May sight how the
#
#
#
#  Variable containing:
#  1.3831
# [torch.FloatTensor of size 1]
#
#
# bet to thing his remest cannot think and thring togeth.
#
# HENRY BOLINGBROKE:
# Dies quirst the hones, for what death,
# And what plery. There not I will chart;
# thy onhit prafing is not not begling.
#
# BIANCA:
#
#
#
#  Variable containing:
#  1.5345
# [torch.FloatTensor of size 1]
#
#
# ble sond more the rest?
#
# WARWICK:
# A are prince was his is brother:
# In your heasten, Warwick, fair the good truith
# Let gives stow me son mides so gentleman it.
#
# LUCENTIO:
# The still.
#
# KING RICHARD II:
# O,
#
#
#
#  Variable containing:
#  1.5922
# [torch.FloatTensor of size 1]
#
#
# bout, the perius is you, are
# Proved is that the fair hear to hear for all and made.
#
# GREGORY:
# Stay with is your wife is dis enemies.
#
# NORTHUMBERLAND:
# Ay, grock, that speak you she rage she most the o'
#
#
#
#  Variable containing:
#  1.6133
# [torch.FloatTensor of size 1]
#
#
# bout say golded.
#
# MARBYELY:
# A gracious no grace, thy men it harm'd;
# Late, I drived to thou at his brother lasterio?
#
# Second Me jestinger:
# These sword cillent not seem to the both:
# That many so you woun
#
#
#
#  Variable containing:
#  1.5731
# [torch.FloatTensor of size 1]
#
#
# by maghing of and remen, that I
# mores that graving for they countrys, so the words?
#
# GONZALO:
# And thou thou had the house these both,
# There by to against thee sees true a fare foreanest,
# Haw trackly so
#
#
#
#  Variable containing:
#  1.5011
# [torch.FloatTensor of size 1]
#
#
# be aside,
# Nor be tent wound, that a shapely huspan a warl.
#
# MENENIUS:
# That he wonds, then me to shall send 'Trul gone sweep.
# 3 KING HENRY VI life, we shall, that, less to consore conting ever destrain
#
#
#
#  Variable containing:
#  1.8061
# [torch.FloatTensor of size 1]
#
#
# bound pried him,
# Do my land's head? What is come,
# The past do was ever the king me father.
#
# DUKE VINCENTIO:
# This strain'd her boy; and she do sorrand
# England away the hoperans precilous saster; do no f
#
#
#
#  Variable containing:
#  1.3731
# [torch.FloatTensor of size 1]
#
#
# be thank have your may weachess!
#
# Boddy:
# And the was my sould's noble have helps and grantoase
# Than the salaty and sit or he, say by the drawn,
# say Kate, or a father is comes I wrike, he's enter him:
# N
#
#
#
#  Variable containing:
#  1.1701
# [torch.FloatTensor of size 1]
#
#
# battee.
#
# SMINIUS:
# Here sick in she be not, thy doth!
# Speak of all the better down,
# But I flown predery would bestample will a very poor's
# Consund of the boundo? I have beseech you.
#
# CAMILLO:
# He had so
#
#
#
#  Variable containing:
#  1.5999
# [torch.FloatTensor of size 1]
#
#
# both be than cannot devoute
# Hast peorge-our worthy was thee:
# And as a venatio, yet of you, cannot say when I womand didser
# Than speak's tent to Verance, anst my lord?
#
# ROMEO:
# But I thank is to his lady
#
#
#
#  Variable containing:
#  1.6497
# [torch.FloatTensor of size 1]
#
#
# buny bestruces thee,
# I' thee, for myself.
# Long discontem with at the structer not with their both
# Wiste: I had are to hours of you'ens and gentle
# 'tis this be to the not.
#
# KING EDWARD IV:
# No, Known my
#
#
#
#  Variable containing:
#  1.5861
# [torch.FloatTensor of size 1]
#
#
# batsed it is to hear it,
# Corfo, what is thou shall seem the words befotsents.
# What how proves to be most been: I have not thou, become
# there such am the manded shoulder dead thee Baster:
# To with agains
#
#
#
#  Variable containing:
#  1.5955
# [torch.FloatTensor of size 1]
#
#
# be as it word,
# The consand wer enough the vice partwell.
#
# DUKE VINCENTIO:
# They brother his heaven shour of marrity,
# Less is meet is in is dead with me the camed
# Of when at her hands it it?
#
# KING RICHAR
#
#
#
#  Variable containing:
#  1.7421
# [torch.FloatTensor of size 1]
#
#
# bouty of a compon alone your peading rement come
# Will spoke act this dispost.'
#
# PAULINA:
# What worshom or row away fight
# Before a pray much all the behols, that call he sword?
#
# PETER:
# That is in all hea
#
#
#
#  Variable containing:
#  1.3894
# [torch.FloatTensor of size 1]
#
#
# batter, I think
# And, what entaguing shall he shalt tell shall after and her stay
# Which not up bones, they shillians of to me robed,
# And when he we have this the hords to you!
# Made on his. Romeo all the
#
#
#
#  Variable containing:
#  1.4664
# [torch.FloatTensor of size 1]
#
#
# be it not blood a might for all news
# Should any the brooking to thought of the dear thou
# you would be not an in this lord.
#
# NISSAMIO:
# Thou were must the ept the belil come to brogging ougonce
# In a quek
#
#
#
#  Variable containing:
#  1.4231
# [torch.FloatTensor of size 1]
#
#
# be him, not be down:
# Sir to of apperight:--drown; to cannot mine,
# That father? Right the guint;
# And his was founded-men this do thee maintived
# I know those your calls to before are make by our gate.
#
# B
#
#
#
#  Variable containing:
#  1.1764
# [torch.FloatTensor of size 1]
#
#
# be by my lady lay for soul
# And crodh him of before found so made rone.
#
# GLOUCESTER:
# I peace up and call the god;
# In the people, as longor for act, thought, sir, get served browern of thy let hild
# My fa
#
#
#
#  Variable containing:
#  1.4909
# [torch.FloatTensor of size 1]
#
#
# bjurts show the ready of and your breathed ey,
# Be his rale shall some friar for what unit;
# Where I be most to feet of your face's engy
# Is for the Duke on me which he then bound from my and deeds.
#
# AUTO
#
#
#
#  Variable containing:
#  1.3242
# [torch.FloatTensor of size 1]
#
#
# bsable signing.
#
# First Senator:
# O, fair of the see of the courring
# To whose the grows and, he did, namely sine,
# And they Clarence of he endower, seem upon me:
# So and sin tock, true with the man,
# Which
#
#
#
#  Variable containing:
#  1.5153
# [torch.FloatTensor of size 1]
#
#
# belling than make you good thy bloody;
# That he maint thell them factive, with is
# Have both I servssal rest revenge,
# Intent fasing the frown the libercerning deder.
#
# TRANIO:
# One joy with the boud! a Lad
#
#
#
#  Variable containing:
#  1.8626
# [torch.FloatTensor of size 1]
#
#
# be is damish.
#
# GLOUCESTER:
# And nusio, foot be accome,
# Where I swall not lischer, my mistress at here fastal you ears:
# But Rome, I have thought you hays.
# What we would here's sond.
#
# PAULIHA:
# Here come.
#
#
#
#  Variable containing:
#  1.1982
# [torch.FloatTensor of size 1]
#
#
# bbbeth you thine,
# And your bear the restrembersh, the kix's, better life:
# And me with the wirst. Wemp julition.
#
# CAMILLO:
# Your worth gener Richard! be his swert to his
# so false he rights in bids your s
#
#
#
#  Variable containing:
#  1.7775
# [torch.FloatTensor of size 1]
#
#
# both being encessures not
# Signiobs friend thy suffer, who molour so my some will,
# And her wons, when, prospets their say
# As desert! O, it down for rang to this never:
# You thus any and years in his frie
#
#
#
#  Variable containing:
#  1.5648
# [torch.FloatTensor of size 1]
#
#
# burry elder and
# To pearing to in them your down thou can, thy lady again.
#
# DUKE VINCENTIO:
# What's be love, then, now, he did of thou dares asted hath shall,
# Which bear thought fall me twousence and div
#
#
#
#  Variable containing:
#  1.4060
# [torch.FloatTensor of size 1]
#
#
# burle unto your would times in name
# then and come, good fortupple of my could parting, how me would,
# That I plyef and I am not come pursele's speak.
#
# KING HENRY VI:
# Where's battle, and and spring fortu
#
#
#
#  Variable containing:
#  1.2677
# [torch.FloatTensor of size 1]
#
#
# be sound the face, our dead is that
# love fieldement-sorrows and all ploar their word, woe
# And an not plack of my kings our swords better,
# With the true him cannot well, have stainher, I in king have no
#
#
#
#  Variable containing:
#  1.5978
# [torch.FloatTensor of size 1]
#
#
# bA, and how thou with my lady.
# If all the branged thou are will gone, there is so rises of the supts
# That that sake, 'tis my brothes out the law
# his hand, this straight to his love
# Be make there so the
#
#
#
#  Variable containing:
#  1.5219
# [torch.FloatTensor of size 1]
#
#
# birsly chaster, as with you
# Let then shape not take the pray and
# a amon, best to should not mercy, he ward of me?
#
# CORIOLANUS:
# Thy knight will not bear so creety again;
# Cast in memor do admer sorrister
#
#
#
#  Variable containing:
#  1.5028
# [torch.FloatTensor of size 1]
#
#
# be my life
# The peron the son,
# And dare, imploy; there and betches Juliet, there of heaven are
# With hather talks for be nothing, there the night sent these love shine mys the revey;
# We in you and I spee
#
#
#
#  Variable containing:
#  1.5465
# [torch.FloatTensor of size 1]
#
#
# bat then, and time can good now hat
# Of the sulatio own your lord?
# Then the fire, accuse, they he of my house struck,
# Belive me in his life, thy case thou better
# Of a will there wrong is your brother to
#
#
#
#  Variable containing:
#  1.4036
# [torch.FloatTensor of size 1]
#
#
# bat not she die man!
# That that cause to thee will to mire be of your fortune
# And but of not to perfection, farth to more to the unlander
# The mbeen or mination, your brother thou sented bear to much
# Of
#
#
#
#  Variable containing:
#  1.6880
# [torch.FloatTensor of size 1]
#
#
# be wears!
#
# PETRUCHIO:
# Why, the world and enough noble broke throne woe
# To seek you out't.
#
# GLOUCESTER:
# And soo-last purnly you do John, my friends;
# Pest one a hand from your so now,
# To seel my reath to
#
#
#
#  Variable containing:
#  1.5965
# [torch.FloatTensor of size 1]
#
#
# bedal breaks with bear upon bear
# With such me, sir, a honour ecrey, elards,
# And lack'd what were you that therefore your grace by letter--
# Were brother of her be is thee,
# Whilds she fut is bidel sir; w
#
#
#
#  Variable containing:
#  1.6843
# [torch.FloatTensor of size 1]
#
#
# by much leave that scate's.
#
# SMILINA:
# Your mean of bide, once,
# No.
# I'll daptings self, and thy so with place
# This down a king,
# Curse straining eart:
# Hate, then she had the fing friarting happat:
# Sir, w
#
#
#
#  Variable containing:
#  1.3999
# [torch.FloatTensor of size 1]
#
#
# be fair hast,
# My good father; or fearing earth and faint,
# When where have bury and entranisless of you shall bleeding
# In kneel it shall good forntage thee the duke.
#
# KING RICHARD II:
# Where all my depos
