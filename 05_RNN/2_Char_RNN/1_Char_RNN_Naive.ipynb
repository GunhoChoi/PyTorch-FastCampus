# %% [markdown]
# # Character Recurrent Neural Network
# - Mimicing Shakespeare's writing style
# - Naive RNN
#
# ![alt text](./SimpleRNN.png)

# %% [markdown]
# ## 1. Settings
# ### 1) Import required libraries

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

# %%
import unidecode
import string
import random
import re
import time, math

# %% [markdown]
# ## 2) Hyperparameter

# %%
num_epochs = 10000
print_every = 100
plot_every = 10
chunk_len = 200
embedding_size = 150
hidden_size = 100
batch_size =1
num_layers = 1
lr = 0.002

# %% [markdown]
# ## 2. Data
# ### 1) Prepare characters

# %%
all_characters = string.printable
n_characters = len(all_characters)
print(all_characters)
print('num_chars = ', n_characters)
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# num_chars =  100

# %% [markdown]
# ### 2) Get text data

# %%
file = unidecode.unidecode(open('./data/shakespeare.txt').read())
file_len = len(file)
print('file_len =', file_len)
# Out:
# file_len = 1115394

# %% [markdown]
# ## 3. Functions for text processing
# ### 1) Random Chunk

# %%
def random_chunk():
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

print(random_chunk())
# Out:
# es blush'd at him and men of heart
# Look'd wondering each at other.
#
# CORIOLANUS:
# Hear'st thou, Mars?
#
# AUFIDIUS:
# Name not the god, thou boy of tears!
#
# CORIOLANUS:
# Ha!
#
# AUFIDIUS:
# No more.
#
# CORIOLANUS:
# Mea

# %% [markdown]
# ### 2) Character to tensor

# %%
def char_tensor(string):
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return Variable(tensor).cuda()

print(char_tensor('ABCdef'))
# Out:
# Variable containing:
#  36
#  37
#  38
#  13
#  14
#  15
# [torch.cuda.LongTensor of size 6 (GPU 0)]

# %% [markdown]
# ### 3) Chunk into input & label

# %%
def random_training_set():    
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %% [markdown]
# ## 3. Model & Optimizer
#
# ![alt text](./embed_rnn_decode.png)
#
# ### 1) Model

# %%
class RNN(nn.Module):
    def __init__(self, input_size, embedding_size, hidden_size, output_size, num_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.embedding_size = embedding_size
        
        self.encoder = nn.Embedding(input_size, embedding_size)
        self.rnn = nn.RNN(embedding_size,hidden_size,num_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
        
    
    def forward(self, input, hidden):
        out = self.encoder(input.view(1,-1))
        out,hidden = self.rnn(out,hidden)
        out = self.decoder(out.view(batch_size,-1))
        
        return out,hidden

    def init_hidden(self):
        hidden = Variable(torch.zeros(self.num_layers, batch_size, hidden_size)).cuda()
        return hidden
    
model = RNN(n_characters, embedding_size, hidden_size, n_characters, num_layers=2).cuda()

# %%
inp = char_tensor("A")
print(inp)
hidden = model.init_hidden()
print(hidden.size())

out,hidden = model(inp,hidden)
print(out.size())
# Out:
# Variable containing:
#  36
# [torch.cuda.LongTensor of size 1 (GPU 0)]
#
# torch.Size([2, 1, 100])
# torch.Size([1, 100])

# %% [markdown]
# ### 2) Loss & Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
loss_func = nn.CrossEntropyLoss()

# %% [markdown]
# ### 3) Test function

# %%
def test():
    start_str = "b"
    inp = char_tensor(start_str)
    hidden = model.init_hidden()
    x = inp

    print(start_str,end="")
    for i in range(200):
        output,hidden = model(x,hidden)
        output_dist = output.data.view(-1).div(0.8).exp()
        #_,top_i = torch.max(output_dist,dim=0)
        top_i = torch.multinomial(output_dist, 1)[0]
        predicted_char = all_characters[top_i]

        print(predicted_char,end="")

        x = char_tensor(predicted_char)

# %% [markdown]
# ## 4. Train

# %%
for i in range(num_epochs):
    total = char_tensor(random_chunk())
    inp = total[:-1]
    label = total[1:]
    hidden = model.init_hidden()

    loss = 0
    optimizer.zero_grad()
    for j in range(chunk_len-1):
        x  = inp[j]
        y_ = label[j]
        y,hidden = model(x,hidden)
        loss += loss_func(y,y_)

    loss.backward()
    optimizer.step()
    
    if i % 100 == 0:
        print("\n",loss/chunk_len,"\n")
        test()
        print("\n\n")
# Out:
#  Variable containing:
#  4.6440
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# b>y9~m
# 4dkthOF/IzHkD6e$2r'Agr\<kU"@gT$LA5e
# onrc(ykU~YN_ZP<u+;B}:yL4}P#[+g1$=if<(=oU(8	&\#_w\8R#i"z3j<u=7*hN}/:R11J/[_^`TQ'V}
#
#
#
#  Variable containing:
#  2.3813
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bull mf hithaflfong, Gove'd ars mathord thip maistpere aouy chiy arrerend me mards in lourhe herle thather
# Woveun picif, hutd machy helor warsid the the lour me bis a lutn
# Woge laing, ar harendt my pot
#
#
#
#  Variable containing:
#  2.0971
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by tage the the he.
#
# Fillir
# The as in, st!
#
# I lonle hater, youn ve'd not sder.
# Hes, and ore mis af heress,
# Hat the fan? nowhis he axest wid ther stenuf thesfr sirfed that whak bend tile; sian is mertin
#
#
#
#  Variable containing:
#  2.1463
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breCpmy uf that that the one cilt, of the geees theer here the on he sfre'lt of the lites hese,
# IW
# UCETTENIO:
# This nod sall hereech and endon blound coud'd geefles.
#
# LOULARE LINO:
# Wher? is weth me der
#
#
#
#  Variable containing:
#  2.0727
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but haw my not I tood the -of and fortere frith tone say wiscent, I plalt, and fire yave houd and the mouk;
# Thinc'd: oe wing of coy a be we ke coud theseone sorft airs genter pake withe a cond cong, to
#
#
#
#  Variable containing:
#  2.0786
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by ward;
# But icher to wuth all old the tt of pon parse,
# Tay:
# A dead to and fillins my stimer, hone.
#
# ARIO:
# I for pite ipyd?
#
# AUSIAN:
# Cown
# Preart and sauthy the were that coof. Gow nlough peoly for bria
#
#
#
#  Variable containing:
#  2.1729
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brours they Andring,
# Tone lew at,
# Of sood to buck what the that is live my prown.
#
# Coffore suns,
# But and peprome, woldant,
# But one, and peme cond of,
# In to prest your foriome, foreso in own somen,
# Bres
#
#
#
#  Variable containing:
#  2.0081
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blepay here preer, the she day not of here thee wadvact kess my somer frome's her froceds,
# In bease farse shall at fis.
#
# DLOBEOREw:
# Where the implerive grive, and you but she have stack fays,
# So to of
#
#
#
#  Variable containing:
#  1.6366
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by to in hath my, lord.
#
# Sike of frattcomires, has the fall chat sads
# And would and wall of as then that feath hom meave bettly acpinger.
# Sectifpiny.
#
# HOLIE:
# Sentese have deather do forsing, and him to
#
#
#
#  Variable containing:
#  1.9488
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bess and sen liet.
#
# DUMELLOLANGARUS:
# Why rearsters sill a plees
# To the and nears in speort.
#
# VIORINGENTER:
# Nor court you so thst po was to come,
# I surce; all ar your diss or hone there,
# To undly to pin
#
#
#
#  Variable containing:
#  1.7092
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bi
# verew:
# What a and Sood a deemorge frees, fating.
#
# KUCEL:
# Senver tize of heart.
#
# SLASTIUS:
#
# CORIOLANGBULO:
#
# Pith of that it thou, I nay fror dies you fron the ntremeit of yoursy that thy diesily what
#
#
#
#  Variable containing:
#  2.0672
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble, then you here cornot me love's here as the chil. Beast warrefarwing you spoon; and this band we shart we bet,
# What thus the pret in lough the with strilipe:
# That or he keless, thesed the fust,
# Yet
#
#
#
#  Variable containing:
#  1.7153
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble grime the faster
# To the burgens
# ul is elden he vim foldest, me, 'd pronged dishantablosbro? I well he bA gall grace him is your have the from he is the gove I here and gave he meaves to may you, th
#
#
#
#  Variable containing:
#  1.5175
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bit ost heart, perried!
#
# Pecan the moves that may the rince your thy beart Mare and sing a well him and had sond and as is be unst be thy reads swy tame a see as the peat's, roownry and and and news he
#
#
#
#  Variable containing:
#  1.9595
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble that so his shath to may stretemed at ou me my may, be the of-unde of uncandlens nevere;
# And the lates,
# To wouse, be flies be: and the lattle, when them
# Angu hath a whild ham is home the mainting.
#
#
#
#
#  Variable containing:
#  1.9057
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# boather's speard
# That meased spalch,
# At the worn me; sood of rost.
#
# KENRY CINCENTIO:
# There low my to;
# To the tages pard, not too I say there all so the that so somerce his to to be lost more, by thime
#
#
#
#  Variable containing:
#  1.7375
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bre on to come, planss love all be fathing appin to we lord--
# It me if bethe carrescly moth that expone befor the matter resiver,
# That it the decome
# I the with his seen of he
# of with my know the pall M
#
#
#
#  Variable containing:
#  1.7363
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bled ford and of me dentless'd as the crance a hap be id not the would no must mine have what face's grobet be in Lenting she is come forded stair have a patter titied I forse of would what a restak, i
#
#
#
#  Variable containing:
#  1.6550
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but, you last count, in the hadstad all have like this merder thou watail.
#
# VIONTARI:
# Both time his with you have to thy might the sold restike comply,
# Jriston in shilts to Prove, not pase or of frown.
#
#
#
#  Variable containing:
#  1.4363
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# buck was not last sput.
# I'll aron thing here the seath than then when be deal you mon it how leave on in that I him swelve a the will Murder.
#
# JRIALNAN:
# I hear would my son good.
#
# CcAPELICS:
# A lies hos
#
#
#
#  Variable containing:
#  1.6965
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brothen's the raid the vaith blate stay him disconseed to where
# Be the gras kneether;
# What I kirst them grom Edwer langed your onour sack! make.
#
# PRKINGBRYCAS:
# Greasunt, to the meap the reardante.
#
# LEO
#
#
#
#  Variable containing:
#  1.8709
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but mist bed God the let your decoust,
# And.
#
# GOUMINI:
# That that thee and veris.
#
# KaNI farse the drady the stayed and there mother thyserved.
#
# KING EDWARD:
# Gut parfolnol surty
# They lord sill timerenged
#
#
#
#  Variable containing:
#  1.5608
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bresision.
#
# ROMEO:
# Go, so to him when the curse:
# I this hid a boy him apanence eet he caced to been never no are sound
# My are,
# And by hereed that as of Glight which her her bost moth a dit. How,
# Though
#
#
#
#  Variable containing:
#  1.5050
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bere tell chands man she dound:
# Spurponst
# Themons he't a man such therenden, here resents ove a most the with mark; me to she hath may nage, of as I do may man here be the king parsand loady that made
#
#
#
#  Variable containing:
#  1.8268
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble a childer dracious!
# Which fear he drup prison,
# And yeth and such here to hath tifuln; soot I was for him.
#
# Lifplewerch been some agatent I let a for it to you not so mone men, my jusine! deadiuder,
#
#
#
#  Variable containing:
#  1.6747
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bere to put curmice and bon come mality latian, truth bey,
# The and and the bus faire sporn; be them let the flautes? fast but my lord.
#
# CASTER:
# I conflies:
#
# DUCKI:
# Which bine,
# And, and thou it in heard
#
#
#
#  Variable containing:
#  1.6828
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble at him.
#
# MENENIII:
# Nor me.
# Now, that shill not his so hath strant!
# And, that I supous that theery his brokes the trrothermend to shore and good a the broms twith and that be the from all my shout o
#
#
#
#  Variable containing:
#  1.7736
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bre and should,
# I will news
# Than here of the vonation doth alore from your pard! do grave by pengen,
# My hone ademen that 'tinwerticasy and endors the have his dained amen;
# And your the she Kere's a tha
#
#
#
#  Variable containing:
#  1.4842
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bother tonguery be no land, away be in ones; now coull sheld hast the frie bustent devisbal:
# And might no be should deserven,
# To orcove,
# The banisoray some, and hath,
# Throod thy love resomel's! God be
#
#
#
#  Variable containing:
#  1.6231
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble sport in pray to my a grance:
# She some nuch crishour seemad:
# And
# To whill my uppold she dryster: shall dishold doth the daughter is seep to well teet remise the set, that courtuen, they stay whead
#
#
#
#  Variable containing:
#  1.7036
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bounts id any!
#
# KING RICHARD:
# I him agair;
# Rold the quile Clayy,
# Even to my lord of alles be liffiance, I will the gents laster, freethour is not fee herefore the so he death, merrof besto, lo,
# Of an o
#
#
#
#  Variable containing:
#  1.6884
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broint, and with to the ploos prings but his so,
# Unlike reto the licks gad
# again him senfoustrous house,
# And let is this repord it lord,
# My lord-no many those puses is by the were up all of the pass,
# W
#
#
#
#  Variable containing:
#  1.7589
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brant make up me virst my belieitory vire it Clantlice this to my draces.
#
# MERCUTIO:
# Why say to her be let here is death.
#
# AUTIO:
# A says and yound and painty:
# But be have not to my sporn'd me of your s
#
#
#
#  Variable containing:
#  1.5176
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belt he in the orcurd is labios a fill gentlead,
# On he rointangly thou a feath, and curse him;
# Haster--for my: and the ten that werow, as I well but, he criard, are haves have honour
# As distre
# of dreat
#
#
#
#  Variable containing:
#  1.7072
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brokes give with by in that breath, when and then, may, be the queen think with my lreath less did me that implood me, I come be you gody of whath that well be hear die men with the slearter'd's say yo
#
#
#
#  Variable containing:
#  1.6620
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beans me and Cluck unliederer not curse for you marring the criend Green despess this atter is dead.
#
# DUKE VINCENTIO:
# Since heard forther:
# Which so hold hope it prefeach; have morn of house I wence res
#
#
#
#  Variable containing:
#  1.4845
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brespait it of a for make sistion,
# Thou perpices,
# For hearforeingesself the obechaties take pound and the like of this act his tood of your your contaly, one is prays this your heaver'd virets not that
#
#
#
#  Variable containing:
#  1.8266
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breaves.
#
# KING RICHARD II:
# Sir, expers on your leave:
# How to be as you were with comman,
# And expelmy.
#
# Man is was parest it for sings of the work's comesser what wrom nettaled himsty roves the way of y
#
#
#
#  Variable containing:
#  1.7795
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brie.
#
# DUKE VINCENTIO:
# For is that sir, and my toom,
# Which and lookers with wail!
#
# STARIUS:
# She allar, a trares the senuling the deam the feart heart sweet longer would death,
# But is bose done will dot
#
#
#
#  Variable containing:
#  1.5228
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brance,
# And her in his duke is bo to would there may queen make for lord, some make think fight.
#
# PADIO:
# No, made bad our peartionour is him treidity and what pray, I croper and lord there than preafou
#
#
#
#  Variable containing:
#  1.8355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bearius of
# and vily is no done my by love name and so alcolloy too have with a aregness: the devise the gone to his hold soul and destrar be hearsell
# To bespell.
#
# MARIANA:
# Not think sonsthou to thee ar
#
#
#
#  Variable containing:
#  1.2593
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bure the heaven, for him; but my done:
# From thou would to should for your fland one and be'd he malest my wuther, better and is minds show,
# Forthard her a so,
# And heart
# More?
# He Marging the vily to but
#
#
#
#  Variable containing:
#  1.8169
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bard the kind that my fear for to have to my death
# Comello, a this the deazed
# enither more wend my feart:
# Come.
# Yourself:
# Thank frething,
# The she pray:
# And conatious to the detis them God, were a from
#
#
#
#  Variable containing:
#  1.6609
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beter now Nort the love to here a remered, speaker my libest and bring him, this bear doy, my pate?
#
# Nurse one a more tell king?
#
# KING RICHARD II:
# Comes?
#
# DUCHESS OF YORK:
# Low'd not allow, good my free
#
#
#
#  Variable containing:
#  1.6286
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bel, freed-hold of though the boor
# Thy durth.
#
# BUCTONCA:
# I not not so not an he so on dean'd kints we kings soul stroddary which make some his soul thou, but!
#
# First and all the are brothen as a rancul
#
#
#
#  Variable containing:
#  1.7642
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bed me badoy;
# They their joless:
# His come the world that be men the lord;
# Mack of me to must sun is your have bedenmerty, infall it is fereful these mean me scelly them and she many with well the count
#
#
#
#  Variable containing:
#  1.5948
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# baging of the masted I would be abon me to thou as the come and beend:
# Though didst shall like plack is mark'd, what from he will encle.
#
# LADY:
# For my lestate so thou caunt a pitard, by no me to breach
#
#
#
#  Variable containing:
#  1.7887
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bet it thou majes on the place:
# Sich that to hath a roys afford.
#
# HENRY GREY:
# Becommandsil that will shold he hearts,
# I presis him all famust.
#
# PETRUCHIO:
# Secal be make do the strrcaiss
# Spake of threat
#
#
#
#  Variable containing:
#  1.6668
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bend; and the true rest here my not for me we word, but doughnes thou had in pack of sime! Hast where, 'Will fall men and hath of Rome hame, whiles and lies; for his many o' the house,
# No head,
# Our mai
#
#
#
#  Variable containing:
#  1.7047
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beance thou like good, that compay as thou the may, on the horse, but the trible, you gasten, and sacces brings and with at did her office or of you have and thy fere her.
#
# KING HENRY VI:
# Has not here
#
#
#
#  Variable containing:
#  1.6976
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# becalts me for nechitian
# And Anguted wabe shill me.
#
# KING RICHARD II:
# O king me resent thou hand queen a beep,
# From grouble of conting of the say of vign weelly thinks conishy betwing the mouth: acall
#
#
#
#  Variable containing:
#  1.5642
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be a are speak the ride of his speak his, what honour devild and and come to be perste, what goom in the reven.
#
# PROSPERO:
# Sway to should no hustice of Colack, on she heave,
# Swort swally.
#
# DUKE VINCENT
#
#
#
#  Variable containing:
#  1.6772
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# buet,
# Dignimina?
#
# TRANIO:
# All be worth, and counter enterning him:
# For then all noble her that that caster prison, if under here the never this black'd blood very the trought the lannot comforns?
#
# BOPN
#
#
#
#  Variable containing:
#  1.3990
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble than the presenting that in the live;
# O heaven to make in the severest to the word in this a this root the surderer
# To strong your need other, with our somethee and now the chatest law where long a
#
#
#
#  Variable containing:
#  1.6131
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bood you come in honour'd enter die, night.
#
# NORTHUMRON:
# Gold he stay;
# The wonance to a lible offovaly the Tange.
# Secures one die?
#
# NORTHUMBERLAND:
# O' connot send the deach will this and reveres, O'll
#
#
#
#  Variable containing:
#  1.5549
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bon you,
# Morne and my deless. Woother, the aly were love justipe:
# To thou arting thee and the jestious.
#
# DUKE VINCENTIO:
# I strengen not cantace.
#
# HERMIO:
# O, thing show she I do the laste
# To chilf,
# He c
#
#
#
#  Variable containing:
#  1.7283
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# better will is not in holding my counterer be thee daughters's the niel me it so been no canick.
#
# LORD POMENENIUS:
# Of thou have table bearst hall the ort greatch's nurse then tood good not a son and on
#
#
#
#  Variable containing:
#  1.8768
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bears of my bestake my nauth the spailence your soul,
# I maving, that I have praustal the any call that'd of the for but fartor.
#
# CLADY OUKE:
# I words of heaven they sake the have show do seep to such so
#
#
#
#  Variable containing:
#  1.7120
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bather lack of these that I have the sterd is my fourt that made them's lack hone
# Hatch any that I death:
# There I'll we death home, an her shall be the death he thy done the prike.
#
# AUTOLYCUS:
# Now; if
#
#
#
#  Variable containing:
#  1.6906
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but do name for surman disconmess pray:
# For not not they she death: Now of me the she lasters any much should ground doth and one the may all will all by that my good many my fair andrether with ever b
#
#
#
#  Variable containing:
#  1.4971
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but warrerer made not thou birnest in tell,
# With lient, that in sir.
#
# Second
# Till his swiffold!
# she wrot his worl would be may not by that I much contenty ege that nor thee to
# All breathe in
# hight,
# The
#
#
#
#  Variable containing:
#  1.5444
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bad, this upon wide:
# Ye' my eye, the Longs
# That seep than that bless any sir'd so faces the harber'd, were them loves death, and his food the sword, he fire all truster the soul.
#
# KING RICHARD III:
# Sho
#
#
#
#  Variable containing:
#  2.1341
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# both voom, here aftencly did on I have be all that no him dear hear such it of I do his presend, if that be the perons himn to look upon
# In here here, thou, my so, sir, in hell, if the world happy's ar
#
#
#
#  Variable containing:
#  1.6505
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blows so bustain.
#
# ESCALUS:
# I do tames counter the wind,
# Hus been were in when none of shim, should the make though to the discontent, you
# Afully desels with a have do soveldon of will stiraty again, h
#
#
#
#  Variable containing:
#  1.4166
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# boy shall grown:
# Here me begzonour reantatess the painst of the curse love here, chill
# The store all that come the repencher: what the womanise:
# By thing, which him the consuled good spirit the find my
#
#
#
#  Variable containing:
#  1.5748
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belich?
#
# Shephount,
# Antels we the love reparder with be thou seep'd ensole, The kiss,
# And evense, it are my capends, ganemother should the king that my hath being the boldial disciost be field will goo
#
#
#
#  Variable containing:
#  1.8590
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blie of my permicel is slain: you, I word, Aughod fave,
# Will care the perity, my lords field him.
#
# PRINCE EDWARD IV:
# Called tear, as the here father,
# And how they lovery broke, but ell, it seed command
#
#
#
#  Variable containing:
#  1.3369
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# been have heas o' the king the fives a fear few hereion the fear
# Take are your damft,
# The blament
# My frief woman their busing.
#
# BRUTUS:
# But death, thou calls in me would so, grace.
#
# First Sakenated of
#
#
#
#  Variable containing:
#  1.7015
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beeding crown me? to make
# To not with strrance that parth your old, my for fool in the are the begest with the recears to my worsh in at anom we woments sleep, and well a place with the praye' to so be
#
#
#
#  Variable containing:
#  1.6083
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breaked the shall lies me?
#
# BERTENSIO:
# A matterny of mine, here.
#
# KING RICHARD III:
# You, bedawarder,
# Yeal and so hono makes dinerty.
#
# MORY:
# I can honour let, suste, the sit is my has is discan with fat
#
#
#
#  Variable containing:
#  2.1450
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bread of thou disband.
#
# PETRUCHIO:
# Have I will I knew of them and his warwat thy eater cisore just the king foul against for pray's fatite you dispeeps it is life. The he like of death?
# The reasine the
#
#
#
#  Variable containing:
#  1.8158
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but fraision lies that the nursed had to from him favens stop anance your soul cousinely for not for a vilian's you, see it would than mean,
# And voimy so nace the sir, curse-forth you destrest thy lord
#
#
#
#  Variable containing:
#  1.3282
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# being, I know may, and son am the sorr harthech, your very; and sir.
#
# KING RICHARD III:
# I pled good good to piped of his all that.
#
# GLOUCESTER:
# What be you with house his a to scare, but joys,
# And she
#
#
#
#  Variable containing:
#  1.7514
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bliely conderical then foing in thou loves
# Upon your but the revere do: and and the fatefut thou same with I beso did cause this treater:
# My think his bound are lord,
# To success,
# And the nery men court
#
#
#
#  Variable containing:
#  1.6910
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bless.
#
# LADY ANNE:
# I'll burreign of you thank dispangant doth gentlemy the rid whited love of they tell as you.
#
# ARTISBAS:
# Ay, way to the more be Edward die.
#
# PRINCE come,
# The sticuro's baster:
# I do he
#
#
#
#  Variable containing:
#  1.8524
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be dead; and fairence:
# Come,
# And a somed his rainor with before to high your sats
# it.
#
# DRANDS:
# You knowher see the man had in noe heartain is just my heart:
# What I comes of thy prince
# Dike or need a gr
#
#
#
#  Variable containing:
#  1.5702
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bus follow I will perselse make of Edward fall and Mercuem'd and many of the all of Poonio her you not I heady with by good you sees fie'll my first the deliver for they infe be sonce him and for.
#
# ANG
#
#
#
#  Variable containing:
#  1.7949
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blood of a gall the mine warld to the clood we are me with then, all not any canted it our any my solding
# Three heard lent in our with my falter, and humbled the flaremengerel,
# That bean appay'd
# As new
#
#
#
#  Variable containing:
#  1.7292
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be the enched, have your the would he was all of bean shall;
# Bidle the will be a' thises,
# And Errard;
# I same?
#
# MARIOLANUS:
# I hard!
# Leaves end not peran queen,
# Ay, I she might by enter him, king him whi
#
#
#
#  Variable containing:
#  1.6365
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bean of my hearth.
#
# PETRUCHIO:
# Blapp, and thre?
#
# LADY CAPETRUCHIO:
# My had stray the soul I not plead?
#
# VOLUMBERLAND:
# I must thou have there, in the devined, and the greapenent me he rear'd seen for he
#
#
#
#  Variable containing:
#  1.6882
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brevour and flour shel near's beet in we hand: which love and Both will deceign old exther noble my master, are be nor but selful:
# These had enjoy seen to father be
# Here a truchers were his batter, he
#
#
#
#  Variable containing:
#  1.7338
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# being held the dead;
# Know news have them: if the that the deser.
#
# HORTENSIO:
# I seemans ubus, for your mack, and been earth you; what whom stretter mands of have and am your deach his worse:
# He some, I
#
#
#
#  Variable containing:
#  1.6286
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble such for fieron the meast
# To my tablest is am I were in,
# Thee the was the miked
# May make saw then for the manise to will the fie wools come my somes arrord.
# Or will but our nurse I'll see their bro
#
#
#
#  Variable containing:
#  1.5408
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# belity
# I am subf there my love they bread armmes about thought agone them to drif son; and the worthy oftence them!
# Your best
# posterly and not or Marred of he steed agon, for that the loveful of things
#
#
#
#  Variable containing:
#  1.6396
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brake save ongled he coy is all with revenge manicl'd.
# What grace a torm
# Thou can, it malice in a heard Vare more eld winds with extrendies;
# 'Tis resire!
# Why, the prove and it have mother clange and wh
#
#
#
#  Variable containing:
#  1.5781
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by spoid me yie heicely seed my hope make about is any yet might have a sad are good soothy content,
# It with break, it before: and are is warrant:
# This death,
# For amough the heart.
#
# Boyand the chumply
#
#
#
#  Variable containing:
#  1.3621
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be nothing be the thou west scoling are hence the tranciends, whose the owny
# Well if there Is the paby fore unjuty, I known it is for met of Griisest oeley of he death of thing have discause to my nale
#
#
#
#  Variable containing:
#  1.8765
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be by:
# Which blame
# being give faid have his peward,
# While, his so, after it is frie a pray of his blood that you are stay it speak him of thou had not but our bistrank in spergaged thank in their grief
#
#
#
#  Variable containing:
#  1.7756
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be the pray,
# To pray
# To fathel sake you not my will rough a perullom:
# Arcaudt the orged then I have she ready
# As scastt
# Fear presorvence, and thou were that your papest.
#
# CAPULEL:
# Hare armber
# That in a
#
#
#
#  Variable containing:
#  1.7663
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beep.
#
# PETRUCHIO:
# Yet for these this so who shoring the queent:
# What prison? With the proft,
# Provinention thee be heart,
# Thou the will good me, do the palling and your forgeth of this haw-fore one hors
#
#
#
#  Variable containing:
#  1.6926
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blaot hear and the well adon: I'll are slace the stressies! hell.
#
# ARGALO:
# There wholemater poin!'
# Thought your groad? I terrandines, and not gence so he gown of death!
# I'll from of fill my shall again
#
#
#
#  Variable containing:
#  1.5467
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# body the are we are impitided, where we have comes you sir, the love attizerselnes, the aid thee of you the sided their the mertriolany speak to her here, that must down.
#
# PETRUCHIO:
# Why, sids me?
# It c
#
#
#
#  Variable containing:
#  1.5095
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beck, and this I at stlay therefore, I will trubt the come, she bid of his orrow to the and you brought for the gracets this a collower's daughter-with a gone me borrices to then and his from blood, an
#
#
#
#  Variable containing:
#  1.4019
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# buers her drombly, whilets,
# That a give mistres?
#
# ARTELO:
# No flain
# To the lann of him to being in orts and hasb of thus may us;
# Of the surress it: I liegh as good thy fitter,
# Our father from murdet by
#
#
#
#  Variable containing:
#  1.5766
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be poabfore was his word; to heaven valour and of Edward, set, three be poor a heart,
# Which shall should with a dread the younge patient.
# Speoken good to found to are thee to all's father.
#
# QUEEN ELIZA
#
#
#
#  Variable containing:
#  1.5253
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# butiled ease is curst thy same to this not a best that here,
# How make the grief whead what not cause.
#
# CORIOLANUS:
# Resired the grovirine.
#
# DUKE VINCENTIO:
# How no his good vorse shall sorriage with nurs
#
#
#
#  Variable containing:
#  1.7447
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breatmer pliving with than euf
# And their reasing sure to his sour now thought Lew, but thou master on his parried a, let he shall again the mother:
# I shine? Sir eny there's he did, and fere betres.
#
# Fi
#
#
#
#  Variable containing:
#  1.7980
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bece of thee of love have the worm.
#
# PAULERIANAN:
# But as nature to more the thus whither here power as what no come the royal more mine then noble the plock, the face to besire she rige,
# And married, a
#
#
#
#  Variable containing:
#  1.8017
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bect him would be them uson your sigemed.
#
# PRINCE:
# Goether the kind me the come, had like then where with how, and the chareve lady in resire been cleave away, of his death, how you come, when masters,
#
#
#
#  Variable containing:
#  1.6437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be this dear contenge. where your wear would near's was at here cantent from frented the queems amoves would paily any parcection?
#
# KING HENRY VI:
# I hast is a saw thy breathed majesty adon the state, e
#
#
#
#  Variable containing:
#  1.7529
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# behies
# I were I may so I but that I have where stores.
#
# CAPULET:
# Or broke it I semphier which bless one and yet with a mine our to hath the woids of power's begenor or the secectest will designess we b
#
#
#
#  Variable containing:
#  1.5335
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beck have I know blood of the doth lords,
# Your grief while thou are the blood and can to to fie!
#
# KATHARINA:
# Then the such then, I have of the bear
# then the garder assentam's should
# That it you.
#
# ISABA
#
#
#
#  Variable containing:
#  1.6577
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brant.
#
# ROMEO:
# No, thee to thee, 'tis a kmander holy the
# artin of that no, thou but seasonners, Romeo, I with
# receipins,
# As it nothings, but be line.
#
# KING EDWALDIAN:
# No liege my bong hath from think t
#
#
#
#  Variable containing:
#  1.4163
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# biders me recalla!
#
# GREGORY:
# O, the wonsh the bound,
# That do I do your hence before your blood against of the cert.
#
# GREMIO:
# Renting against been theerean:
# Even, and thou would,
# That drare be in
# liver,
#
#
#
#  Variable containing:
#  1.6878
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be not of the ond
# come: from a would Claudery rear your good of fear.
#
# Pall our vildred of forget a board fear this have our deads, sir, and thy thing best for something wife, whe king it reasons,
# To b
#
#
#
#  Variable containing:
#  1.4024
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# been Servants end the waily and from thine,
# And, he haste where we all under the do their horse to they will hush that see and thee your will and to I you wry any Servon of his lice, hapely but fall of
#
#
#
#  Variable containing:
#  1.5686
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but of Norfolk,
# Which bints.
#
# PETRUCHIO:
# Now then; every on my boding the subsents.
# Nour rike they from the lord to mine to the with your worls. I well tongues, thing, I gards
# the shall will did love u
#
#
#
#  Variable containing:
#  1.7018
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but to poistleming to-dow, as your be courthious look'd them here with the childress thou honour as allicter'd to me thought on the heath,
# I did unto alone the fill the the commard good foothred, we co
#
#
#
#  Variable containing:
#  1.6927
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but have ween provissed betremen, sir.
#
# GLOUCESTER:
# What,
# To will cur heart
# 'Sold on him not person, trit off Way for thou were this dead solet, age me, but me endle you?
# Thank yet to the selker the mu
#
#
#
#  Variable containing:
#  1.7177
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by twenteans than my moling a poor the neped,
# Us thy fall in all at it: will you too lies their poiss an elmaiot but may be true up you have marire and appower,
# What no them may.-
# Fall shall fair,
# And
#
#
#
#  Variable containing:
#  1.4890
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but
# What thou I didst,
# The bought, not and three his name a harrt of chy,
# And name the call a have queen,
# Say be new, nog what thou do ever faces not, think and wears of come of my prase be faurat all
#
#
#
#  Variable containing:
#  1.7248
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beach trun
# peria to rive a the perish
# Such your marm,
# A port to that bring are for't the rand to the'll son beat the king of all;
# And at it year: then with the crapty, my lady are is than hath acried m
#
#
#
#  Variable containing:
#  1.5614
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beat and fear not from faunts
# God my lord him what model to the loss me, fear be fair state; As saken, bespicions him the many the winded fine, the wife; and if their enemy hell to then queer beart not
#
#
#
#  Variable containing:
#  1.6881
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# better and alron, desire.
# To much of we is please for her wincely, seate thy trows of reach mantage but I am we doubt of thy lord? He the rearing be it our right,
# To thou or then me.
#
# BUCKINGHAM:
# The s
#
#
#
#  Variable containing:
#  1.6304
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beck'd might the poishary
# uname molsion'd.
#
# MENENIUS:
# But fling of not to---pook tell me been might thou
# list, sir, for then pitying, them the jever many perform the grie me not right thee, to be hand
#
#
#
#  Variable containing:
#  1.7251
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# become
# And is he doughter's well thee speak, and be be hear and me into fall pray we wrempreft the heart, what shall pired she's if his saw been,
# Flescess,
# Thou ene the six were do not that he shall th
#
#
#
#  Variable containing:
#  1.4272
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bented to childred in tallfutyier went me shall impo messer, I would find us:
# Even Edward in foll
# To my shust of the foe;
# That is be lips own in: and that poor chain'd in that worls dead, but in my, ne
#
#
#
#  Variable containing:
#  1.7322
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bee many,
# Becied.
#
# DUCHESS OF YORK:
# What, in yet thou have pray him, jedancour'd of I mear grace.
#
# KING RICHARD III:
# Then go the pasish I say, the dear hears thee she his my reasons, I sporious a have
#
#
#
#  Variable containing:
#  1.6347
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# berice to there the queen the pit a thou befend?
#
# CAPULET:
# Girful an are her her to hiest to the charce of a may he why day their the most.
#
# LORD BENRES:
# A licked.
#
# MERCUTIO:
# The bospited be, are not h
#
#
#
#  Variable containing:
#  1.6087
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broy what the sweet my a pate; to have should in our child thought the fater I call'd an one way, that your
# give the vo!
# I present:
# I be the delive, sir, fie for good not, so tears to care the sweet be
#
#
#
#  Variable containing:
#  1.4535
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# best then thou have me, spervingst as everess to-morrowery is gaint too comprift time, sirs tape, by my dead.
#
# PRINCE:
# But.
#
# PROSPERO:
# No partial trument not our dead
# track the hard's newgnets follows
#
#
#
#  Variable containing:
#  1.7684
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brick in pardones, but I man.
#
# GLOUCESTER:
# Thou her.
#
# ANGELO:
# He reto me niret you man
# The band
# To perjurous to shophe him, then with a mothem Anton in't tears.
#
# HASTINGS:
# I will have their faman:
# All-
#
#
#
#  Variable containing:
#  1.6430
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bellieesed away.
# And leave I am more to the prove Mongended stander fondure the father!
# No; surity you serve as yonorwor orne to thou are yet from your seed.
#
# First for purpire,
# From to may.
#
# Third Ang
#
#
#
#  Variable containing:
#  1.7162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be brother out Romeo, and good talk was no more, how I sent tears?
#
# KING RICHARD III:
# A bean but, say good now
# That is next her to the house I may Ed me but it and come, having her newd and a hand;
# And
#
#
#
#  Variable containing:
#  1.6786
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brain in with rough as when much to that so told my fairs me the comfort. For his too will be was brother.
#
# Live am make him daing:
# Of him shall pray for me court it.
#
# CLARENCE:
# By guest that will he t
#
#
#
#  Variable containing:
#  1.5019
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be him, leave a trison thou are rair of tether a true-hatchful the divist, mother's death,
# Thee of thy all heard of his nothing word.
#
# First Servant.
# So well with them perention myself to king are
# Fore
#
#
#
#  Variable containing:
#  1.4483
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# buch os defect of this thee a spore my rather as malituse to so make a the own, and that I has blood.
#
# KING RICHARD II:
# My presenced, the danger-greation and sir, thou lay the sapfully first were a sep
#
#
#
#  Variable containing:
#  1.6521
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# buck such are then and he humber:
# Were not to the storet servantage,
# Sir done;
# Sir.
#
# FRIAR LAURENCE:
# Why, from this love me conder's breather of the land;
# By know a very blood comes Shall in the lord t
#
#
#
#  Variable containing:
#  1.3989
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be the prewell men belo see harse with stone and was in without the law not away, if he slee--most part for I do edestion of therefore where's one an a bedle Bont their banish but thee: 'Pill! a have y
#
#
#
#  Variable containing:
#  1.7728
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# busing make when shall see-sime,
# Which was be Business three you: Even me off that that male
# thou hast it is you have had swear illing marring
# In good noble plain:
# Shill and not cut of this bastes you
#
#
#
#  Variable containing:
#  1.5883
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bed to the post with, let make in the should live; the untheil a more his busin!
# I was any and Getle early with here I must say the crown,
# There's I downess crown as guon your give his buckisfora, how
#
#
#
#
#  Variable containing:
#  1.3726
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bund the father,
# Come, the would doubt this neceful go was bece and and should balood,
# And let his father grace well.
#
# KING RICHARD IV:
# This first Sicn
# This contents,
# Which way heir this worse
# What her
#
#
#
#  Variable containing:
#  1.4798
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be as I shall now his young in he birth they lives, I am not speak him stoke our well the night afurred not the swears with a well, and hath hath so sake the canniaintew the lip that she and what a har
#
#
#
#  Variable containing:
#  1.2935
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beet not knows of a bake there with they case a world they to son
# How a day my honour when the cay heard
# That have all him more,
# That me.
#
# FLORIZEL:
# Pistres, or coame the accaint,
# Shalt gall that that
#
#
#
#  Variable containing:
#  1.7677
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be he all, you love me and thou age! I leave of must fair with arms.
#
# CURTIS:
# Is a coundster me; lade:
# For your again, or then nost:
# Which oft, all he hass'd a powers faights: go.
#
# LADYsA:
# I commid a t
#
#
#
#  Variable containing:
#  1.5129
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but he is through the all he spalties forget the warward small by their teme shall be as by the cruque,
# Whire our for he of much the consuray'd these unto all welcauted a citimes slares the wuts the to
#
#
#
#  Variable containing:
#  1.3986
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be by do you;
# Not his bad here?
#
# Secover my lord his with her meant thee.
#
# ESCALUS:
# What here, what be her deal,
# Here, to thou stird, let pleoused.
#
# BIOLUS:
# What weegnes,
# Yeam,
# and meant it with the co
#
#
#
#  Variable containing:
#  1.7562
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bfore and my foul to dow'd that's this are Rome, bear
# This shall be founds virtuous, this
# And this charte.
#
# PAULINA:
# Yet myself?
#
# ROMEO:
# Whose and leave my so, Suming this an every the counsed thing me
#
#
#
#  Variable containing:
#  2.0865
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# berone is she is could is dies in propost.
#
# KING EDWARD IV:
# Let is thee breathed mean of senting of convelper'd the vengerous thanks
# A stay's countring of deed that bread
# tir, my good new to whit in th
#
#
#
#  Variable containing:
#  1.9134
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bused he land 'am are for you tempors shink crose poor breath, 'tis upon then I traicted which this are to are thee how shall bed the winter soul.
#
# Second Capper,
# And reck'd sixed and in brother, I wis
#
#
#
#  Variable containing:
#  1.6699
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bund a kinds days, seemed are me in the king pirle in think my lord, curse, would deed, the valour a houser?
# What shall that confectaighres to make my good never certs all told and newer it live and lo
#
#
#
#  Variable containing:
#  1.6737
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# buse.
#
# GLOUCESTER:
# He so you shald he shate him are countory son: and this though,
# I will the weak
# That is,
#
# CORIOLANUS:
# What heart against thou art a shall bittle have pass the ladishads.
#
# BUCKINGHAM:
#
#
#
#  Variable containing:
#  1.4658
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but, I woulds, Wastrears,
# And and Plavous of this brother thought of you have their loved fault of a swords, I'll my name on my many is the seass to this graciot insulus; as the, not said twarm if
# I ma
#
#
#
#  Variable containing:
#  1.5001
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be me body of face,
# And a frind,
# I tance may your conce conving the dood thee may you, good,
# And bounds to in thy for my long the pity!
# Of encounter so father are pray them
# Of the saint.
#
# LUCIO:
#
# MINAN
#
#
#
#  Variable containing:
#  1.5916
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# by he is.
#
# MISTES:
# Your say!
#
# ISABELLA:
#
# TRANIO:
# Would come sunford him, whiles in curst the tempress the very procling of not hear both if the into the souls unather good be very,
# And hang the lord sh
#
#
#
#  Variable containing:
#  1.0580
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bet there's a master, and gentle,
# In he have sworn this she callower are me?
#
# ANGELO:
# But stricit your ange we know me then with deservale your man on; you?
#
# DUCHESS:
# O tender'd.
#
# FLOMETEN:
# And blood i
#
#
#
#  Variable containing:
#  1.9329
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broke in honour pale the give he hath behold.
#
# Ctost thee part.
#
# MARCIUS:
# How and pause me and time to be Clarencious
# To paped dayss.
# Thee love, on of to made her a man, no we are of call, sir, I was l
#
#
#
#  Variable containing:
#  1.5441
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bray's them make then, gentlemony the other, this is that good dost to do done, I the thiedy in him tears then windess
# though tales;
# Has that the assure that let almoy!
#
# Corishard this sea titters to M
#
#
#
#  Variable containing:
#  1.5988
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bereponour treats,
# Unlest the repart
# Since thou deside denitial one see upons to shall savener see they me see, sir, and hast some a faets a Cuilstard, and not, and the now'd me his lord stand of buck?
#
#
#
#  Variable containing:
#  1.4286
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bressience; sir:
# And was resone, hangs againss may minisures you wasider with my use, this heaven that caused the resight, than or?
#
# HENRY HIZEL:
# And stretch'd shame to from you have camal, Let me be h
#
#
#
#  Variable containing:
#  1.6196
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bet is now, I they arlishard for the fif: is as his good of the take the present; yemary,
# The day instooked be, the what more e'st.
#
# KING RICHARD II:
# She he sents!
#
# KING RICHARD II:
# She do not tell in
#
#
#
#  Variable containing:
#  1.5179
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but the cault.
#
# Third Mercure atter!
#
# CAMILLA:
# O frair have this news.
#
# CAMILLIUS:
# Come his honour, shall that not becaud good mould a mother that wife.
#
# BARIANA:
# Which and down she have heaven countri
#
#
#
#  Variable containing:
#  1.4747
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brent?
#
# KING RICHARD II:
# Such to more him a mine and the, this weak of my world, paring my suit:
# The Defent my blamblastce: and some city well lives the world;
# Sir, which should by my kinders; whom rem
#
#
#
#  Variable containing:
#  1.4077
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# baniswing my benained upon madam.
#
# QUEE faret the tongue, to God; an in fal poor had done, that more all be against the sent she duke to they noble back have port.
#
# LUCENTIO:
# And it thy grace: but main
#
#
#
#  Variable containing:
#  1.3381
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bearful he
#
# GREMII:
# Why, and eyes, I sie,
# Swear and this man.
#
# HERMIONE:
# Grace with my banish?
# A saw, and beate my unone and what with for then what conder my son the first, duke to ever angelves,
# Must
#
#
#
#  Variable containing:
#  1.5457
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bition in the man: he has toon which on sweets by pretret 'done this not become-love homes find him, Richard eye, being thought,
# But bear,
# The heart
# Will let: and withind by have lord him; but suace!
#
#
#
#
#
#  Variable containing:
#  1.4160
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be promather stards.
#
# MERCUTIO:
#
# Firstruching reace.
#
# DUKE OF AUWILE:
# Then, to my stay of thee and of fired with honour said.
#
# Firstress the pres lie would that what roves with procures with brother si
#
#
#
#  Variable containing:
#  1.8140
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bean a lage the gods of so subjection the mannot father, behiefore we resolved,
# Them roared mustio,
# Menerle old within,
# Or made elve thee beot out of with devil, ever beseech.
#
# GRUMIO:
#
# DUKE VINCENTIO:
#
#
#
#  Variable containing:
#  1.4555
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brave soul his hours a grave me he wold their black'd that come, your stand it! I makes time timing of not be hour denthe, no monder tell
# The harded of let lang.
#
# COMINIUS:
# For not a tongue?
# Go, how si
#
#
#
#  Variable containing:
#  1.6467
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bucely of so throusway, care's father be fair'd, say, burn desperve him.
#
# HENRY BOLINGBROKE:
# And susping hear may speak.
#
# PERDITA:
# Should hath your opported them by fly fearing the wint,
# Having for hea
#
#
#
#  Variable containing:
#  1.2506
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but from therefore this honest a mother for the perpose,
# Away!
#
# WARWICK:
# Most answeep of therefore to that not the amand than he say in the honourselves go more in the yound clack in exfecture,
# And tho
#
#
#
#  Variable containing:
#  1.3583
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# besio copes, and that of core can by the tarrow.
#
# LEONA:
# Why, he so die, heart it hast up a think tones of
#
# LEONTES:
# How to him the dark's named stome when all father thee; that of Paris
# Bounded!
#
# PROS
#
#
#
#  Variable containing:
#  1.8078
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be mine of his dispoyed, there in a power of a mail senry!
#
# First Senvior, and a spures infull in wints an it juedst gurse my mannow;
# And dong in his messengentive.
#
# KING RICHARD II:
# Hold with thee
# Lov
#
#
#
#  Variable containing:
#  1.4751
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be good he's take of my bonder find to what thou set it bady good good kindle a heaven is the more on
# Cauldon the bad, what now contend.
#
# GLOUCESTER:
# Now like it or him so grace the are and a great he
#
#
#
#  Variable containing:
#  1.3620
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bo grace; the Busic presect you have his lips the good to bard say to him was you have counds this small oreant dreasering.
#
# DUKE OF YORK:
# You make still
# The desire for
# thee you live in they with uncur
#
#
#
#  Variable containing:
#  1.6876
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breath, and are endured of the queen of their heart that bue gods all go many
# I have his son: you deanful content, but you arms: bold, gound the fight father you shall spurge: then in this die poor and
#
#
#
#  Variable containing:
#  1.7768
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be,
# When counce these had by give the well sucker.
#
# HENRY BOLINGBROKE:
# Why die tempt.
# The and our harvel futh these protection welcope well in a score proud expects of Giditest unto like no at,
# Of this
#
#
#
#  Variable containing:
#  1.3884
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bures as beafford's bloody of was I am prove you.
# And thou are an our thy shalt swordly gentlement the so.
#
# LADY ANNE:
# A purser, but the surly enemies, and
# With the see keep present and should a subjec
#
#
#
#  Variable containing:
#  1.5267
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bus thus lives not?
#
# ESCALUS:
# He sing, this?
# If thee his sciffort but not Lune
# With the would think thinged in you, gentle of thy grace to that many gracious of not the fails, thou be lives say lant ma
#
#
#
#  Variable containing:
#  1.5024
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# ble be prince that see their sens and Bolingbroke beseech in him, man.
#
# CAMILLO:
# If let be sorrow been knach in the eyed;
# I dead,
# By day, and, for his pardine to part these in sistern'd be.
#
# Clown:
# Wha
#
#
#
#  Variable containing:
#  1.4976
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# braws.
#
# HERMIO:
#
# GLOUCESTER:
# The will shall be toward.
#
# BAPTIV:
# He sit; bold find to no no fair to worthy not that from the abours.
#
# PRINCE EDWARD:
# For grom whose counted;
# You not speing would rose of
#
#
#
#  Variable containing:
#  1.5330
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breat God? and this pray to stay my very kings of I may.
#
# ESCALUS:
# Praise to the brother to my more that much me, beast, conthee.
#
# MARCIUS:
# You must love to approose, then have show smile, let to at co
#
#
#
#  Variable containing:
#  1.7728
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# be unreck, but thy soverely house optroyor polizes of creeds cousin Lucent, seemake in win
# Aloblong, I'll such we much steed, is seent.
#
# Tholt ease my learn'd too will thy lielad.
#
# CAMILLO:
# Some to pow
#
#
#
#  Variable containing:
#  1.4804
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bed me,
# he batter?
#
# TEBWARD IV:
# Sir, and what on the last not led them denound:
# I hear and you; throughies a pale:
# There thou to connether on you has fair, my both on bound, or this dead, and not may t
#
#
#
#  Variable containing:
#  1.5776
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# breath.
#
# First Marcius; their subject in your gentleman, and to in ere beggard we will many bosh sheph worn charved but watch that good love to he wear: for his.
#
# First My Richard malquld king by talk
#
#
#
#  Variable containing:
#  1.6780
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bloods of honour been cristy foul content friends night, tell'd those aid of true the need, deebf and he halk and their bares:
# Then Thou pare thee
# If you have reagh him.
#
# DUKE VINCENTIO:
# Sick their a t
#
#
#
#  Variable containing:
#  1.5655
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# brack,
# Thinking.
#
# LUCENTIO:
# Loved as the good to it even my faed I have a gellow us appears of the gurrish humble to my execession as with in a most is thy remool's at Cature the juststions of these ay
#
#
#
#  Variable containing:
#  1.5936
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bether my brace.
#
# PETRUCHIO:
# This other with the hard in seek word and faunt fenter siles me my bady;
# Now I have some the part them, have I shave the in me awayen upon not of heaven of which he come we
#
#
#
#  Variable containing:
#  1.4654
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but your dear at on heaven,
# And tell tens,
# Be one of the si to my foot pleasure sad to say crial his straise hear to condies.
#
# Pirst made be entertacteron on his but lives of it the world.
# Now, in Here
#
#
#
#  Variable containing:
#  1.9224
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but in the repsions hence sweat me as is ray,
# Not her bring a comfort's forbory,
# With son, this young with a stremiss her heres of surpling of you, pointed the ser, and you heart them be mother.
#
# CAMIL
#
#
#
#  Variable containing:
#  1.4764
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but live in you;
# Your flement so beti'd death of warrantnce, such are lenife to their brother.
#
# CAPULET:
# Beingared to the dance:
# Shall prove
# But a have mean me me, a gods your latis have a take tener o
#
#
#
#  Variable containing:
#  1.3162
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# buse women them with Prince.
#
# SICINIUS:
# Prove, a thou thoughsent,
# Thee make suching to for justice mind your good so, if the matius for the more hath first With the offless is such on, the gene my us u
#
#
#
#  Variable containing:
#  1.3963
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# blow
# How beon bewied, and makes the prince her sond his see and here the pears
# Shall you say, I sound, and think no mother his the heavence againstlemences that we peerishes lords,
# Op prince and trumpe
#
#
#
#  Variable containing:
#  1.5616
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# busing he may bland'd aflery-falmble so fate, and a mother witatest that from ank by soul death, and the come prive of honour breaties fither them been be
# Cooping and my leize, we faces gried, a seat t
#
#
#
#  Variable containing:
#  1.4212
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bund less Edward his husband's farron:
# Here,
# Let such?
#
# MERCUS:
# O, is he with
#
# LERY VINCENTIO:
# Peling our surses to heir me their fard you, for not cousin,
# The shall not:
# And with him.
#
# Third Curpit th
#
#
#
#  Variable containing:
#  1.7411
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# business,
# No, sing
# A broke some, sir, to so my mind these comnows
# be my belest till my cromataal, remenched resolve of this poor report it a speak in all banish'd.
#
# KING RICHARD II:
# Why, you true, he s
#
#
#
#  Variable containing:
#  1.4159
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bloward, and care thou our
# Of it; and you'll true; when I not them this mother, for thou widwry.
#
# LEONTES:
# Inere hath the offection of his our eyes of thrildowered commond towtity decried of her way, m
#
#
#
#  Variable containing:
#  1.8648
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# best these friend in the remembress his hand myst in see,
# And all
# The come, all less,
# To rem:
# Thou cheephious the possess wife,
# As due of my of the made as put thousand be were the are-receove is good
#
#
#
#  Variable containing:
#  1.4061
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# betters to me.
# Comes
# to himselfide it
# Long your way fact partiked and noble, all not rold of the remeng they two by o' thought; strends, the goods kiss, yet sacred gentlember crusing were but?
#
# FRONLEY
#
#
#
#  Variable containing:
#  1.7222
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# beath in a mauding:
# Pedious breath, the bugned to as you are stire it singer sent ifle ere my wivold to the colstull a child and batch shall prove of then I'll lords;
# Or strefut, our bracious country a
#
#
#
#  Variable containing:
#  1.5293
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bryed;
# My blood, gods his danger his,
# Which grown Lode it know, let it been
# The cleying from
# The doth beggen sade
# To ither this but early feep with your gide.
#
# SICINIUS:
# My wind worthy is throng me: wh
#
#
#
#  Variable containing:
#  1.6590
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# but to comes Edwnever from the furthy to for the daid some finger finds;
# I down.
#
# LEONTES:
# You art father say thou can me fortune to murting win the name, for my ence, thou she lend-chance, then you! w
#
#
#
#  Variable containing:
#  1.4900
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bucties.
#
# KING RICHARD II:
# O, it That be the ground
# Thou constant.
#
# Second Murderer:
# Conso blession with the preman:
# The caster for this fain this tears.
#
# THOMAS:
# which a thousant was my rich'd like me
#
#
#
#  Variable containing:
#  1.6103
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# butiness done, some wind of the nor that the could it or courtio my bo, of heart, on thing poin, but suft drink to the chile;
# If them him, what in prayer:
# The quectenat, and my lords, so it as their pr
#
#
#
#  Variable containing:
#  1.5641
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bution:
# He know my mile it you forn Mush it you have shall you have I praised, my prince, do the king of your beasured the great her brother,
# Sweet little may, less apporrence, I have to dissies.
#
# SLBE
#
#
#
#  Variable containing:
#  1.7955
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# betile:
# What I promish of my will consom in the sendle birth's peace, amon this make upon surpain stay?
#
# CORIOLANUS:
# What in they armsirgall my love.
# So looks is you unto that guiltise.
#
# First Servingm
#
#
#
#  Variable containing:
#  1.6084
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# broke thou art the father, peak,
# And west she come and your case wantost in my baness the king come you, and that worth 'tis your suffed the king of the fire of he shall in at unfews, so he would be th
#
#
#
#  Variable containing:
#  1.2544
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bucemy me have those would reade look to me old senter of a wills not to this pray inawn that in they can doth matthe capo his ration the end way with there make
# The safeen: will congent the shake him
#
#
#
#  Variable containing:
#  1.4674
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# bluge of my king breaty my looks were take the promisgen to his part,
# Swear as the carror, I'll been the confession comman,
# And have becompearn.
#
# YOMSOSTIO:
# So means, what thou be my lay time to my lor
#
#
#
#  Variable containing:
#  1.6077
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# buneding of the Duke thy lounds, my lord, I do be this soul,
# That it assicel pity here; for made be send of your hone,
# I see husband a speak that the hands. I make me, and their gatterly, that death, t

# %%
weights = torch.Tensor([0.26, 0.24, 0.25, 0.25])

for i in range(10):
    print(torch.multinomial(weights, 1))
# Out:
#  2
# [torch.LongTensor of size 1]
#
#
#  2
# [torch.LongTensor of size 1]
#
#
#  3
# [torch.LongTensor of size 1]
#
#
#  0
# [torch.LongTensor of size 1]
#
#
#  0
# [torch.LongTensor of size 1]
#
#
#  0
# [torch.LongTensor of size 1]
#
#
#  3
# [torch.LongTensor of size 1]
#
#
#  2
# [torch.LongTensor of size 1]
#
#
#  2
# [torch.LongTensor of size 1]
#
#
#  2
# [torch.LongTensor of size 1]
