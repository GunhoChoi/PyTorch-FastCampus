# %% [markdown]
# # Neural Network with Cubic Data
# - y = x^3 -3x^2 -9x -1
# - 5 hidden layers

# %% [markdown]
# ## 1.Import Required Libraries

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from torch.autograd import Variable
from visdom import Visdom
viz = Visdom()

# %% [markdown]
# ## 2. Data Generation

# %%
num_data = 1000
num_epoch = 5000

x = init.uniform(torch.Tensor(num_data,1),-10,10)
y = (x**3) - 3*(x**2) - 9*x - 1

noise = init.normal(torch.FloatTensor(num_data,1),std=0.5)

y_noise = y + noise

# %%
# visualize data

input_data = torch.cat([x,y_noise],1)

win=viz.scatter(
    X = input_data,
    opts=dict(
        xtickmin=-10,
        xtickmax=10,
        xtickstep=1,
        ytickmin=0,
        ytickmax=500,
        ytickstep=1,
        markersymbol='dot',
        markercolor=np.random.randint(0, 255, num_data),
        markersize=5,
    ),
)

viz.updateTrace(
    X = x,
    Y = y,
    win=win,
)
# Out:
# 'pane_359580af3d036a'

# %% [markdown]
# ## 3. Model & Optimizer

# %%
# fully connected model with 5 hidden layer

model = nn.Sequential(
            nn.Linear(1,20),
            nn.ReLU(),
            nn.Linear(20,10),
            nn.ReLU(),
            nn.Linear(10,5),
            nn.ReLU(),
            nn.Linear(5,1),
        ).cuda()

loss_func = nn.L1Loss()
optimizer = optim.SGD(model.parameters(),lr=0.0005)

# %% [markdown]
# ## 4. Train

# %%
loss_arr =[]
label = Variable(y_noise.cuda())

for i in range(num_epoch):
    output = model(Variable(x.cuda()))
    optimizer.zero_grad()

    loss = loss_func(output,label)
    loss.backward()
    optimizer.step()
    
    if i % 100 ==0:
        print(loss)
        
    loss_arr.append(loss.cpu().data.numpy()[0])
# Out:
# Variable containing:
#  222.1463
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  222.1004
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  222.0602
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  222.0170
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  221.9643
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  221.8974
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  221.8088
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  221.6971
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  221.5534
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  221.3457
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  221.0325
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  220.5192
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  219.5946
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  217.6515
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  212.5467
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  193.7264
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  149.2523
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  144.8996
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  143.4939
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  142.0391
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  140.4760
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  138.7132
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  136.6244
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  133.9719
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  130.3074
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  125.1758
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  118.0744
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  110.2283
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  103.6340
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  95.6275
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  85.6002
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  74.3824
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  61.4886
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  49.0367
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  39.2603
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  39.1447
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  51.0621
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  52.4250
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  41.5896
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.6394
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  32.0782
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  48.7377
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  42.9197
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  44.1551
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  34.0355
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  44.8808
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  25.0765
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  39.1571
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  28.7053
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.2888
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %%
param_list = list(model.parameters())
print(param_list)
# Out:
# [Parameter containing:
# -0.8063
#  0.2756
# -0.3384
# -0.2312
#  1.0235
#  0.3479
# -0.8969
# -1.2947
#  0.9956
#  0.2972
# -0.5797
# -0.1252
#  0.6384
# -0.0883
# -0.2995
#  0.0454
#  0.8496
# -0.0338
#  0.6862
#  0.3218
# [torch.cuda.FloatTensor of size 20x1 (GPU 0)]
# , Parameter containing:
# -0.7433
# -0.9472
#  1.2563
#  0.8898
# -1.2675
# -2.2851
# -4.8587
# -2.1046
#  0.7892
# -1.9741
# -2.3304
#  0.4639
# -3.5723
# -0.8805
# -1.9278
# -0.4515
# -0.1570
#  0.5505
#  0.5085
#  0.6041
# [torch.cuda.FloatTensor of size 20 (GPU 0)]
# , Parameter containing:
#
# Columns 0 to 9
# -0.0456 -0.0174 -0.1533 -0.1943  0.0979 -0.1207  0.0443  0.0214 -0.0236  0.1495
#  0.0637 -0.1597 -0.0220 -0.0656 -0.0152 -0.1843  0.7717  0.3784  0.1990 -0.1872
#  0.3490  0.1381 -0.2096 -0.0584  0.9192  0.2428  0.4596  0.6372  0.8295  0.0445
#  0.5133 -0.2750 -0.1276 -0.1513 -0.3708 -1.1743  2.2676  1.0024  0.6615 -0.8689
# -0.0668  0.2516 -0.0533  0.0369  0.5393  0.5934 -0.0942 -0.0356  0.5506  0.5698
#  0.5423 -0.4598 -0.8600 -0.3965 -0.2431 -1.0806  2.8134  1.1561  0.6431 -1.1396
#  0.1709  0.4291  0.2618  0.2001  0.4868  0.5583 -0.2284 -0.0679  0.5060  0.4414
# -0.1419 -0.1874  0.0193 -0.0348 -0.0186 -0.0779  0.1531  0.1444 -0.0174 -0.1331
#  0.0054 -0.1964 -0.2110  0.0929 -0.1767 -0.1704  0.1288 -0.0675  0.0696  0.2200
# -0.1989  0.2055 -0.0250 -0.1385  0.7246  0.4690 -0.0262 -0.0968  0.6815  0.3134
#
# Columns 10 to 19
#  0.0341  0.1563  0.1763  0.0985  0.0449 -0.0164 -0.1512 -0.1791 -0.1729 -0.2031
#  0.3377 -0.1536 -0.2217 -0.0166  0.3642 -0.0252 -0.0194 -0.3623 -0.1011 -0.1880
#  0.1296  0.2327  0.5809  0.1942  0.2308 -0.1370  0.8214 -0.1599  0.6830  0.4880
#  1.0298 -0.1117 -1.6821 -0.0548  0.7912 -0.0868  0.1438  0.0254  0.4581  0.4511
# -0.2016 -0.0583  0.6886 -0.0689  0.1755 -0.1617  0.2721 -0.3091  0.0847  0.2334
#  1.1602 -0.2884 -1.8591 -0.0636  1.3113  0.1052  0.1462  0.0338  0.3802  0.2665
# -0.2384  0.0375  0.7194  0.0957 -0.2586 -0.1523  0.5133 -0.0965  0.3120  0.1124
# -0.1975 -0.0023 -0.1886  0.0105 -0.1294 -0.0489  0.1644 -0.0347 -0.0556 -0.1357
# -0.1083  0.0420 -0.1239 -0.0791 -0.1139  0.1456 -0.2085  0.1237  0.1605 -0.0483
# -0.0010 -0.0904  0.8885  0.0741  0.0035 -0.1541  0.4257 -0.0590  0.4379 -0.0425
# [torch.cuda.FloatTensor of size 10x20 (GPU 0)]
# , Parameter containing:
#  0.0589
# -0.4870
# -0.1056
#  0.1138
#  0.0076
# -0.0817
# -0.0482
#  0.1859
# -0.1735
# -0.4424
# [torch.cuda.FloatTensor of size 10 (GPU 0)]
# , Parameter containing:
#  0.0131 -0.0117  1.4676 -0.4456  1.1460 -0.3090  1.0205 -0.1219  0.0198  1.1027
# -0.1691 -0.2306 -0.1159  0.0272  0.2566 -0.2769 -0.3057 -0.1174  0.2117  0.1017
# -0.0958  1.0898  0.7624  3.2849 -0.4913  3.9599 -0.5705 -0.0397  0.1774 -0.3633
# -0.1891 -0.2306  1.3743 -0.2352  0.5455 -0.4040  0.8173  0.0918  0.2235  1.1305
# -0.1194  0.0848 -0.1103 -0.2672  0.0697 -0.1140 -0.1805  0.1058  0.0741 -0.1759
# [torch.cuda.FloatTensor of size 5x10 (GPU 0)]
# , Parameter containing:
#  0.2854
#  0.1179
#  0.1637
#  0.1676
# -0.1944
# [torch.cuda.FloatTensor of size 5 (GPU 0)]
# , Parameter containing:
#  2.4422 -0.3561 -5.2835  2.0527  0.4379
# [torch.cuda.FloatTensor of size 1x5 (GPU 0)]
# , Parameter containing:
# -0.4490
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# ]

# %% [markdown]
# ## 5. Visualize Trained Output

# %%
win2=viz.scatter(
    X = input_data,
    opts=dict(
        xtickmin=-10,
        xtickmax=10,
        xtickstep=1,
        ytickmin=0,
        ytickmax=500,
        ytickstep=1,
        markersymbol='dot',
        markercolor=np.random.randint(0, 255, num_data),
        markersize=5,
    ),
)

viz.updateTrace(
    X = x,
    Y = output.cpu().data,
    win = win2,
)
# Out:
# 'pane_359580b5bd7c32'

# %% [markdown]
# ## 6. Visualize Loss Graph

# %%
x = np.reshape([i for i in range(num_epoch)],newshape=[num_epoch,1])
loss_data = np.reshape(loss_arr,newshape=[num_epoch,1])

win3=viz.line(
    X = x,
    Y = loss_data, 
)
