# %% [markdown]
# # Neural Network with Cubic Data
# - y = x^3 -3x^2 -9x -1
# - 5 hidden layers

# %% [markdown]
# ## 1.Import Required Libraries

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from torch.autograd import Variable
from visdom import Visdom
viz = Visdom()

# %% [markdown]
# ## 2. Data Generation

# %%
num_data = 1000
num_epoch = 5000

x = init.uniform(torch.Tensor(num_data,1),-10,10)
y = (x**3) - 3*(x**2) - 9*x - 1

noise = init.normal(torch.FloatTensor(num_data,1),std=0.5)

x_noise = x + noise
y_noise = (x_noise**3) -3*(x_noise**2) - 9*x_noise - 1

# %%
# visualize data

input_data = torch.cat([x,y_noise],1)

win=viz.scatter(
    X = input_data,
    opts=dict(
        xtickmin=-10,
        xtickmax=10,
        xtickstep=1,
        ytickmin=0,
        ytickmax=500,
        ytickstep=1,
        markersymbol='dot',
        markercolor=np.random.randint(0, 255, num_data),
        markersize=5,
    ),
)

viz.updateTrace(
    X = x,
    Y = y,
    win=win,
)
# Out:
# 'pane_3542e0de36afd6'

# %% [markdown]
# ## 3. Model & Optimizer

# %%
# fully connected model with 5 hidden layer

model = nn.Sequential(
            nn.Linear(1,20),
            nn.ReLU(),
            nn.Linear(20,10),
            nn.ReLU(),
            nn.Linear(10,5),
            nn.ReLU(),
            nn.Linear(5,1),
        ).cuda()

loss_func = nn.L1Loss()
optimizer = optim.Adam(model.parameters(),lr=0.003)

# %% [markdown]
# ## 4. Train

# %%
loss_arr =[]
label = Variable(y_noise.cuda())

for i in range(num_epoch):
    output = model(Variable(x.cuda()))
    optimizer.zero_grad()

    loss = loss_func(output,label)
    loss.backward()
    optimizer.step()
    if i % 100 ==0:
        print(loss)
    loss_arr.append(loss.cpu().data.numpy()[0])
# Out:
# Variable containing:
#  206.2327
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  154.3106
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  107.7555
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  89.2922
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  73.4803
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  54.7178
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  42.2081
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  38.6305
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.6114
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.2215
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.0761
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.0310
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.0382
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.0131
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.0134
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.0014
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.0130
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9955
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9877
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9915
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  37.0011
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9933
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9719
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9639
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9585
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9663
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9582
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9834
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9610
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9605
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9493
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9433
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9407
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9378
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9314
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9361
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9297
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9305
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9271
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9367
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9465
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9448
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9660
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9199
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9123
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9193
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9197
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9334
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9441
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  36.9118
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %%
param_list = list(model.parameters())
print(param_list)
# Out:
# [Parameter containing:
#  0.4124
# -1.1469
#  1.5503
#  1.4824
#  1.0714
#  0.3511
# -1.0062
# -0.4893
# -0.8112
# -0.6280
# -0.5954
#  1.6502
#  1.8854
#  0.5734
#  1.5929
#  1.4927
# -1.1372
# -0.3196
# -0.2959
# -0.4270
# [torch.cuda.FloatTensor of size 20x1 (GPU 0)]
# , Parameter containing:
# -2.6703
#  1.0445
#  0.2310
# -0.3110
# -2.3747
# -2.9311
# -2.2187
# -2.9443
# -2.8392
# -1.1830
# -1.6838
# -1.1596
# -1.6565
# -2.8834
# -1.5742
# -1.7617
# -0.3459
# -2.2191
# -2.0557
# -2.8928
# [torch.cuda.FloatTensor of size 20 (GPU 0)]
# , Parameter containing:
#
# Columns 0 to 9
#  0.0444 -1.0434 -1.0614 -0.8949 -0.2138 -0.0490  1.3998  1.6009  1.4227  0.7925
# -2.0863 -0.3716  0.5802  0.7977 -0.8084 -2.9079  1.1545  1.5676  1.4756  0.9275
#  0.1408 -0.0424 -0.0618  0.0573  0.2054 -0.1160 -0.1032 -0.1808 -0.1492 -0.0371
#  1.3968  0.6030  1.0934  1.1964  1.4759  1.4943 -0.1406  0.0494  0.2876 -0.8871
# -2.0497  0.1095  0.2762  0.4163 -0.4481 -2.9383  1.1117  1.4257  1.3379  0.8541
# -1.9385 -0.3518  0.3509  0.4241 -0.4983 -2.9731  1.1431  1.4546  1.4725  0.7318
# -0.1100 -0.0366  1.2387 -0.0472 -0.0717 -0.1435 -0.0179 -0.8335 -1.7469  0.7201
# -1.9367 -0.7591  0.6331  0.7675 -0.6319 -2.8468  0.8424  1.4594  1.3016  0.8590
#  0.1693 -0.3928 -0.7459 -0.5686 -0.1701 -0.0033  1.2837  1.5519  1.5558  0.6276
# -2.0577 -0.7368  0.4044  0.5315 -0.6253 -2.6681  0.8371  1.3574  1.5580  0.8324
#
# Columns 10 to 19
#  1.1742 -0.4570 -0.0069 -0.0078 -0.1221  0.1583 -0.0154  1.5794  2.0083  2.1993
#  0.8022  0.4586 -0.5094 -1.3171  0.4851 -0.7013  0.1304  1.5463  1.4091  2.2070
# -0.1117  0.0604 -0.2045 -0.0837  0.0472 -0.2406 -0.0566 -0.2113 -0.1125 -0.0198
# -0.9208  1.0305  1.3650  0.9470  1.3005  1.2476  0.4747  0.1099  0.1824  0.0519
#  1.1097  0.3539  0.0377 -0.9440  0.3182 -0.4576  0.6184  1.2189  1.3301  2.3187
#  1.0092  0.3211 -0.3050 -0.9886  0.4256 -0.1754  0.1375  1.1246  1.4666  2.2153
# -0.7497 -0.6403 -0.7443  0.1846 -1.1025  0.2564  0.4141 -1.4598 -0.8023 -0.9469
#  1.1895  0.3674 -0.5468 -0.9325  0.4543 -0.7448 -0.0718  1.3816  1.7056  2.4181
#  1.0669  0.0864 -0.0437  0.1115  0.0909 -0.0712  0.2084  1.3809  1.6930  2.0803
#  0.8357  0.5471 -0.4578 -1.2606  0.4278 -0.4072 -0.1343  1.5149  1.7445  2.2245
# [torch.cuda.FloatTensor of size 10x20 (GPU 0)]
# , Parameter containing:
# -1.8329
# -1.4307
# -0.2181
# -0.7419
# -1.4221
# -1.4243
#  0.6192
# -1.5484
# -1.5780
# -1.4564
# [torch.cuda.FloatTensor of size 10 (GPU 0)]
# , Parameter containing:
#  0.1159 -2.4737 -0.0797  1.1537 -2.0011 -1.9462  1.0152 -2.8276 -0.2926 -1.9615
#  1.7500  0.8315  0.1745  0.0295  1.4281  1.2723  2.4000  1.3221  1.4726  1.0466
# -0.0027 -1.2136 -0.1120  1.7310 -1.6532 -1.4891 -0.4282 -1.5690 -0.2914 -1.4083
#  1.3633  1.2369  0.1580  0.0308  1.2526  1.4210  2.3517  1.0299  1.6933  1.3826
#  1.5555  1.2077 -0.1802  0.0227  1.5274  1.5595  2.2561  1.1096  1.3443  1.4975
# [torch.cuda.FloatTensor of size 5x10 (GPU 0)]
# , Parameter containing:
# -3.2437
# -2.1474
#  0.2478
# -2.1061
# -1.6847
# [torch.cuda.FloatTensor of size 5 (GPU 0)]
# , Parameter containing:
#  2.2768 -1.5765  1.6161 -1.4862 -1.3933
# [torch.cuda.FloatTensor of size 1x5 (GPU 0)]
# , Parameter containing:
#  0.7258
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# ]

# %% [markdown]
# ## 5. Visualize Trained Output

# %%
win2=viz.scatter(
    X = input_data,
    opts=dict(
        xtickmin=-10,
        xtickmax=10,
        xtickstep=1,
        ytickmin=0,
        ytickmax=500,
        ytickstep=1,
        markersymbol='dot',
        markercolor=np.random.randint(0, 255, num_data),
        markersize=5,
    ),
)


viz.updateTrace(
    X = x,
    Y = output.cpu().data,
    win = win2,
    opts=dict(
        xtickmin=-15,
        xtickmax=10,
        xtickstep=1,
        ytickmin=-0,
        ytickmax=500,
        ytickstep=1,
        markersymbol='dot',
        markercolor=np.random.randint(0, 255, (num_data, 3,)),
    ),
)
# Out:
# 'pane_3542e0e41be690'

# %% [markdown]
# ## 6. Visualize Loss Graph

# %%
x = np.reshape([i for i in range(num_epoch)],newshape=[num_epoch,1])
loss_data = np.reshape(loss_arr,newshape=[num_epoch,1])

win3=viz.line(
    X = x,
    Y = loss_data,
    opts=dict(
        xtickmin=0,
        xtickmax=num_epoch,
        xtickstep=1,
        ytickmin=0,
        ytickmax=20,
        ytickstep=1,
        markercolor=np.random.randint(0, 255, num_epoch),
    ),
)
