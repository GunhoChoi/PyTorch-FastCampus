# %% [markdown]
# # Neural Network with 2D Data
# - Neural Network with 4 layers
# - 2D data f(x,y) -> R

# %% [markdown]
# ## 1.Import Required Libraries

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from torch.autograd import Variable
from visdom import Visdom
viz = Visdom()

# %% [markdown]
# ## 2. Data Generation

# %%
num_data=1000
num_epoch=5000

x = init.uniform(torch.Tensor(num_data,1),-10,10)
y = init.uniform(torch.Tensor(num_data,1),-10,10)
z = x**2 + y**2

x_noise = x + init.normal(torch.FloatTensor(num_data,1),std=0.5)
y_noise = y + init.normal(torch.FloatTensor(num_data,1),std=0.5)
z_noise = x_noise**2 + y_noise**2

data_noise = torch.cat([x_noise,y_noise,z_noise],1)

# %%
# data visualization

win_1=viz.scatter(
        X=data_noise,
        opts=dict(
            markersize=5,
            markercolor=np.ndarray(shape=[num_data,3],dtype=float,buffer=[51,153,255]*np.ones(shape=[num_data,3]))
            )
        )

# %% [markdown]
# ## 3. Model & Optimizer

# %%
model = nn.Sequential(
            nn.Linear(2,20),
            nn.ReLU(),
            nn.Linear(20,10),
            nn.ReLU(),
            nn.Linear(10,5),
            nn.ReLU(),
            nn.Linear(5,5),
            nn.ReLU(),
            nn.Linear(5,1),
        ).cuda()

loss_func = nn.L1Loss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

# %% [markdown]
# ## 4. Train

# %%
input_data = torch.cat([x,y],1).cuda()
label = z_noise.cuda()
loss_arr =[]

for i in range(num_epoch):
    optimizer.zero_grad()
    output = model(Variable(input_data))
    loss = loss_func(output,Variable(label))
    loss.backward()
    optimizer.step()
    
    loss_arr.append(loss.cpu().data.numpy()[0])
    
    if i % 100 == 0:
        print(loss)
        data = torch.cat([input_data.cpu(),output.cpu().data],1)

        win_2 =viz.scatter(
                X=data,
                opts=dict(
                markersize=5,
                markercolor=np.ndarray(shape=[num_data,3],dtype=float,buffer=128*np.ones(shape=[num_data,3]))
            )
    )
# Out:
# Variable containing:
#  68.5214
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  63.2572
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  19.6800
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  17.4722
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  15.7753
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  14.4038
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  12.8888
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  11.2582
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  9.3760
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  7.8480
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  7.3190
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  7.0718
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.8624
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.7326
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.6653
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.6134
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.5614
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.5083
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.4389
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.3682
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.3072
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.2701
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.2483
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.2331
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.2242
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.2156
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.2079
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.2043
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1946
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1864
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1805
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1744
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1687
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1624
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1603
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1549
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1507
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1486
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1489
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1450
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1438
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1417
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1412
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1381
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1371
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1341
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1309
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1294
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1285
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  6.1266
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %%
param_list = list(model.parameters())
print(param_list)
# Out:
# [Parameter containing:
#  1.0006  0.3704
#  0.0212 -0.8641
# -0.5265 -0.9388
# -0.0247  0.3726
# -0.1807 -0.5073
# -0.7079  0.8594
#  1.0520  0.5459
# -1.0987  0.2502
# -0.0497 -1.1885
# -0.6721 -0.3403
#  0.4215 -0.7769
#  0.1122 -0.2271
#  0.7061  0.0737
# -0.5351  0.6767
#  0.0307 -0.0288
#  0.4156  0.9384
# -0.6418  0.0994
#  0.8648 -0.1796
# -1.1547 -0.1620
#  1.0124 -0.2104
# [torch.cuda.FloatTensor of size 20x2 (GPU 0)]
# , Parameter containing:
#  0.4415
# -0.6126
#  0.1387
# -1.6824
# -1.4579
# -0.2661
#  0.1088
#  0.7412
# -0.4832
# -1.1438
# -0.2886
# -0.9381
# -1.0335
# -1.2684
# -0.6048
# -0.9223
# -1.6081
#  0.9622
#  0.1651
# -0.7356
# [torch.cuda.FloatTensor of size 20 (GPU 0)]
# , Parameter containing:
#
# Columns 0 to 9
#  0.6421 -0.0411  0.7380 -1.1939 -0.9349  1.3839  0.0909  0.9662  0.3064 -0.9713
#  0.1819 -0.0575 -0.0592  0.7220  0.4367  0.1751  0.1911  0.2938 -0.1516  0.5145
# -0.0651  0.4594  0.4051  0.7076  0.2063  0.3008  0.3447  0.5018  0.2850  0.5748
#  0.0770  0.4897  0.0598  0.3851  0.3911  0.4787  0.5050  0.6577  0.6291  0.0610
# -0.1753 -0.2272  0.0625  0.1655  0.1184 -0.1006  0.0479 -0.1897 -0.1945  0.0010
# -0.6014  0.0790 -0.1660  1.0727  1.6025 -0.6585  0.2696 -0.1021 -0.3705  0.8207
#  0.1056  0.2034 -0.0063  0.6724  0.5160  0.4482  0.1935  0.6087  0.1937  0.1825
#  0.2427  0.1845  0.0578  0.4320  0.2559  0.3359  0.1548  0.5503  0.1397  0.5579
#  0.2291  0.5544  0.3970  0.3228  0.4047  0.5178  0.4436  0.6435  0.4209  0.3623
#  0.2164  0.3204  0.0340  0.4128  0.2288  0.2068  0.3965  0.3988  0.5078  0.0439
#
# Columns 10 to 19
# -0.2456 -0.9310 -0.4648 -0.6757  0.0260 -0.1831 -1.8636  0.6220  1.0475 -0.2602
#  0.1889 -0.0677  0.4088  0.2665  0.0739  0.2826  0.9039 -0.1097 -0.0087  0.1030
#  0.3390  0.3716  0.2359  0.2869 -0.1053  0.1772  0.7629  0.1093  0.0750  0.1830
#  0.2764  0.3889  0.2264  0.4201 -0.1152  0.3896  0.4349  0.0724  0.1859  0.1011
# -0.0566 -0.2279 -0.1939  0.0077  0.1448 -0.0339  0.0593  0.1228  0.0993 -0.0152
#  0.0581  1.8449  0.9738  0.8502 -0.1545  0.2644  0.1696 -0.9071 -0.4364  0.9764
#  0.0469  0.1608  0.4035  0.4310  0.1642  0.4632  0.7247 -0.1190  0.2270 -0.0348
#  0.1421  0.2034  0.6053  0.4420  0.1475  0.3737  0.9389 -0.0573  0.1901  0.4628
#  0.2703  0.1205  0.3231  0.4188 -0.0960  0.3422  0.6042  0.1118  0.0894  0.3047
#  0.2347  0.1626  0.1030  0.5067 -0.0542  0.5448  0.4850  0.0895 -0.1475  0.1858
# [torch.cuda.FloatTensor of size 10x20 (GPU 0)]
# , Parameter containing:
#  1.0761
# -0.8061
# -0.4215
# -0.0771
#  0.0039
# -1.8259
# -0.4350
# -0.2945
#  0.0363
# -0.4832
# [torch.cuda.FloatTensor of size 10 (GPU 0)]
# , Parameter containing:
# -0.1270 -0.0573 -0.1290 -0.0776 -0.2214 -0.1752  0.0138  0.0484 -0.0013 -0.2143
# -0.1614 -0.1103 -0.0133 -0.1959  0.1786  0.0316  0.2643 -0.1967  0.0111  0.1802
# -0.4412  0.1959  0.5664  0.6356 -0.1161  1.5590  0.6644  0.4396  0.5277  0.4431
# -1.8454  0.5140  0.6357  0.0941  0.1509  2.1546  0.3606  0.7117  0.2082  0.2248
# -1.4159  0.5065  0.3013  0.4358 -0.1354  1.5047  0.2753  0.4639  0.2151  0.6216
# [torch.cuda.FloatTensor of size 5x10 (GPU 0)]
# , Parameter containing:
# -0.2547
# -0.1584
# -0.1936
# -0.8476
# -0.0322
# [torch.cuda.FloatTensor of size 5 (GPU 0)]
# , Parameter containing:
#  0.1172 -0.0952  0.1207  0.0339 -0.6190
# -0.0177  0.0676 -0.4101  0.0982  0.0285
#  0.3830 -0.3145  0.6579  1.0751  0.7641
#  0.1905 -0.4012  0.4846  0.6524  0.4865
#  0.1401  0.1277  0.7441  0.5527  0.1577
# [torch.cuda.FloatTensor of size 5x5 (GPU 0)]
# , Parameter containing:
# -0.1272
# -0.0006
#  0.2089
#  0.7798
# -0.3708
# [torch.cuda.FloatTensor of size 5 (GPU 0)]
# , Parameter containing:
# -0.9441 -0.0306  0.6441  0.8009  0.6916
# [torch.cuda.FloatTensor of size 1x5 (GPU 0)]
# , Parameter containing:
# -0.1964
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
# ]

# %% [markdown]
# ## 5. Visualize Trained Output

# %%
data = torch.cat([input_data.cpu(),output.cpu().data],1)

win_2 =viz.scatter(
        X=data,
        opts=dict(
        markersize=5,
        markercolor=np.ndarray(shape=[num_data,3],dtype=float,buffer=128*np.ones(shape=[num_data,3]))
    )
)

# %% [markdown]
# ## 6. Visualize Loss Graph

# %%
x = np.reshape([i for i in range(num_epoch)],newshape=[num_epoch,1])
loss_data = np.reshape(loss_arr,newshape=[num_epoch,1])

win3=viz.line(
    X = x,
    Y = loss_data,
    opts=dict(
        xtickmin=0,
        xtickmax=num_epoch,
        xtickstep=1,
        ytickmin=0,
        ytickmax=20,
        ytickstep=1,
        markercolor=np.random.randint(0, 255, num_epoch),
    ),
)
